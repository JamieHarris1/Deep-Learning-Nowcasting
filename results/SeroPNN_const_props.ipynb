# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os
import sys
import torch
from torch.utils.data import DataLoader, Dataset
from properscoring import crps_ensemble
import random




sys.path.append(os.path.abspath('../src'))
project_dir = Path.cwd().parent

from data_tools.data_utils import SimulateSero, PartialCountDataset, TrueCountDataset
from model_tools.train_utils import BaseTrain, SeroTrain, DirectTrain
from model_tools.models import SimSero, DirectSero
from model_tools.evaluation import eval_sero_pnn, plot_sero_pnn_preds, eval_pnn, eval_direct_sero

start_year = 2016
end_year = 2022
data_split = [5/7, 1/7, 1/7]
seed = 123

D = 40
M = 50
T = 40
Q = 40
N = 4


# 123, 2019, 2023, 15

def set_seed(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.use_deterministic_algorithms(True)

# %%
# Simulate Data
# True counts * Constant sero prop vec * constant delay vec from average across world samples
p_sero = np.array([0.5, 0.3, 0.2, 0.1])
# p_sero = np.array([0.9, 0.0, 0.05, 0.05])
sero_all = ["DENV-1", "DENV-2", "DENV-3", "DENV-4"]



delays_df = pd.read_csv(project_dir / "data" / "transformed" / "DENG_delays.csv")
delays_df = delays_df.set_index("Collection date")
delays_df.index = pd.to_datetime(delays_df.index)

y_true = delays_df.sum(1)[:-2]
y_true_df = y_true.groupby(y_true.index.to_period("M")).sum()
y_true = np.array(y_true_df)
const = 10*np.ones_like(y_true)

denv_df = pd.read_csv(project_dir / "data" / "transformed" / "denv_df.csv")

denv_df = denv_df[denv_df['Delay'] < 60]

# If your original denv_df dates are datetime
denv_df['Collection date'] = pd.to_datetime(denv_df['Collection date'])

start_month = pd.to_datetime(delays_df.index.min())
end_month = pd.to_datetime(delays_df.index.max())

# Create a DataFrame of month start dates as datetime (not Period)
dates = pd.DataFrame({
    "Collection date": pd.date_range(start=start_month, end=end_month, freq='MS')
})

df = denv_df[denv_df['Sero'] == "DENV-1"] \
    .groupby(['Sero', 'Collection date', 'Delay']) \
    .size() \
    .reset_index(name='count')

df = df.pivot(index='Collection date', columns='Delay', values='count')

# Ensure df.index is datetime as well
df.index = pd.to_datetime(df.index)

p_delay = np.array(df.fillna(0).mean(0) / df.fillna(0).mean(0).sum())

p_sero = p_sero[:, np.newaxis, np.newaxis]   # shape (S,1,1)
const = const[np.newaxis, :, np.newaxis]  # shape (1,T,1)
p_delay = p_delay[np.newaxis, np.newaxis, :Q]  # shape (1,1,D)

# multiply to get (S,T,D)
sero_tensor = p_sero * const * p_delay
# sero_tensor = sero_tensor.round()
for s,sero in enumerate(sero_all):
    sero_df = pd.DataFrame(sero_tensor[s, :, :])
    sero_df.index = y_true_df.index
    sero_df.to_csv(project_dir / "data" / "model" / "sero_dfs" / f"{sero}.csv", index=True)
    print("Saving sero: ", sero)


# Create Serotype obj
sero_tensor = []
base_folder = project_dir / "data" / "model" / "sero_dfs"
files = [f for f in os.listdir(base_folder) if f.endswith('.csv')]
for file in files:
    file_path = os.path.join(base_folder, file)
    df = pd.read_csv(file_path)
    dates = df['Collection date']
    sero_df = df.drop(columns="Collection date")
    sero_tensor.append(sero_df)
sero_tensor = np.array(sero_tensor)

sero_dataset = SimulateSero(sero_tensor, dates, T=T, Q=Q, N=N, prop_vec=p_sero)



# Create count obj
delays_df = pd.read_csv(project_dir / "data" / "transformed" / "DENG_delays.csv")
delays_df['Collection date'] = pd.to_datetime(delays_df['Collection date'])

partial_count_dataset = PartialCountDataset(delays_df, D=D, M=M)
true_count_dataset = TrueCountDataset(delays_df)


# End of 2023 appears to have some incomplete data
if end_year == 2023:
    dates = list(pd.date_range(f"{start_year}-01-01",f"{end_year}-12-25", freq='D'))
else:
    dates = list(pd.date_range(f"{start_year}-01-01",f"{end_year}-12-31", freq='D'))
data_split_sizes = (np.array(data_split) * len(dates)).astype(int)

# Ensure dates line up fully, also removing 2023-12-31 as doesn't appear complete
data_split_sizes[-1] = len(dates) - data_split_sizes[:-1].sum()


train_dates = dates[:data_split_sizes[0]]
val_dates = dates[data_split_sizes[0]:data_split_sizes[0]+data_split_sizes[1]]
test_dates = dates[data_split_sizes[0]+data_split_sizes[1]:]


class SeroPNNDataset(Dataset):
    def __init__(self, partial_count_obj, true_count_obj, sero_obj, dates):
        self.partial_count_obj = partial_count_obj
        self.true_count_obj = true_count_obj
        self.sero_obj = sero_obj
        self.dates = dates
    
    def __len__(self):
        return len(self.dates)
    
    def __getitem__(self, index):
        date = self.dates[index]
        obs = self.partial_count_obj.get_obs(date)
        sero_obs = self.sero_obj.get_obs(date)
        prop_vec = self.sero_obj.get_prop_vec(date)
        y = self.true_count_obj.get_y_prop(date, prop_vec)
        dow = date.day_of_week
        return (obs, dow, sero_obs), y
    
set_seed(seed)
sero_props = pd.read_csv(project_dir / "data" / "transformed" / "sero_props.csv")


train_sero_pnn_dataset = SeroPNNDataset(partial_count_dataset, true_count_dataset, sero_dataset, train_dates)
val_sero_pnn_dataset = SeroPNNDataset(partial_count_dataset, true_count_dataset, sero_dataset, val_dates)
test_sero_pnn_dataset = SeroPNNDataset(partial_count_dataset, true_count_dataset,  sero_dataset, test_dates)

g = torch.Generator()
g.manual_seed(seed)

train_loader = DataLoader(train_sero_pnn_dataset, batch_size=32, shuffle=True, generator=g)
val_loader = DataLoader(val_sero_pnn_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_sero_pnn_dataset, batch_size=32, shuffle=False)
# Out:
# Saving sero:  DENV-1
# Saving sero:  DENV-2
# Saving sero:  DENV-3
# Saving sero:  DENV-4

# %%
N = len(sero_dataset.get_prop_vec("2020-01-01"))
sero_pnn_model = SimSero(M=M, D=D, T=T, Q=Q, N=N, hidden_units = [16, 8], conv_channels = [16, 1], embedding_dim = 10, dropout_probs = [0.15, 0.1], device="cpu")
sero_pnn_train = SeroTrain("SeroPNN", lr=0.0003)
sero_pnn_train.train_model(sero_pnn_model, train_loader, val_loader)
# Out:
# Epoch 1 - Train loss: 2.1e+03 - Val loss: 2.48e+04 - ES count: 0
# Epoch 2 - Train loss: 1.8e+03 - Val loss: 2.04e+04 - ES count: 0
# Epoch 3 - Train loss: 1.66e+03 - Val loss: 1.85e+04 - ES count: 0
# Epoch 4 - Train loss: 1.53e+03 - Val loss: 1.64e+04 - ES count: 0
# Epoch 5 - Train loss: 1.41e+03 - Val loss: 1.44e+04 - ES count: 0
# Epoch 6 - Train loss: 1.28e+03 - Val loss: 1.21e+04 - ES count: 0
# Epoch 7 - Train loss: 1.18e+03 - Val loss: 1.14e+04 - ES count: 0
# Epoch 8 - Train loss: 1.06e+03 - Val loss: 9.14e+03 - ES count: 0
# Epoch 9 - Train loss: 9.59e+02 - Val loss: 1.06e+04 - ES count: 1
# Epoch 10 - Train loss: 8.49e+02 - Val loss: 8.17e+03 - ES count: 0
# Epoch 11 - Train loss: 7.5e+02 - Val loss: 7.77e+03 - ES count: 0
# Epoch 12 - Train loss: 6.37e+02 - Val loss: 6.09e+03 - ES count: 0
# Epoch 13 - Train loss: 5.78e+02 - Val loss: 5.31e+03 - ES count: 0
# Epoch 14 - Train loss: 4.85e+02 - Val loss: 4.33e+03 - ES count: 0
# Epoch 15 - Train loss: 4.07e+02 - Val loss: 3.23e+03 - ES count: 0
# Epoch 16 - Train loss: 3.42e+02 - Val loss: 3.76e+03 - ES count: 1
# Epoch 17 - Train loss: 2.84e+02 - Val loss: 2.24e+03 - ES count: 0
# Epoch 18 - Train loss: 2.45e+02 - Val loss: 1.84e+03 - ES count: 0
# Epoch 19 - Train loss: 2.06e+02 - Val loss: 1.53e+03 - ES count: 0
# Epoch 20 - Train loss: 1.78e+02 - Val loss: 9.68e+02 - ES count: 0
# Epoch 21 - Train loss: 1.47e+02 - Val loss: 1.07e+03 - ES count: 1
# Epoch 22 - Train loss: 1.25e+02 - Val loss: 7.3e+02 - ES count: 0
# Epoch 23 - Train loss: 1.13e+02 - Val loss: 9.38e+02 - ES count: 1
# Epoch 24 - Train loss: 1.02e+02 - Val loss: 6.11e+02 - ES count: 0
# Epoch 25 - Train loss: 1.14e+02 - Val loss: 3.08e+02 - ES count: 0
# Epoch 26 - Train loss: 85.3 - Val loss: 5.05e+02 - ES count: 1
# Epoch 27 - Train loss: 1.04e+02 - Val loss: 5.39e+02 - ES count: 2
# Epoch 28 - Train loss: 70.8 - Val loss: 3.73e+02 - ES count: 3
# Epoch 29 - Train loss: 93.7 - Val loss: 3.35e+02 - ES count: 4
# Epoch 30 - Train loss: 65.0 - Val loss: 4.48e+02 - ES count: 5
# Epoch 31 - Train loss: 64.9 - Val loss: 3.1e+02 - ES count: 6
# Epoch 32 - Train loss: 70.6 - Val loss: 4.22e+02 - ES count: 7
# Epoch 33 - Train loss: 61.7 - Val loss: 2.84e+02 - ES count: 0
# Epoch 34 - Train loss: 68.5 - Val loss: 3.25e+02 - ES count: 1
# Epoch 35 - Train loss: 58.8 - Val loss: 2.93e+02 - ES count: 2
# Epoch 36 - Train loss: 55.8 - Val loss: 2.46e+02 - ES count: 0
# Epoch 37 - Train loss: 55.5 - Val loss: 3.37e+02 - ES count: 1
# Epoch 38 - Train loss: 88.1 - Val loss: 3.58e+02 - ES count: 2
# Epoch 39 - Train loss: 71.2 - Val loss: 3.05e+02 - ES count: 3
# Epoch 40 - Train loss: 64.5 - Val loss: 3.38e+02 - ES count: 4
# Epoch 41 - Train loss: 56.7 - Val loss: 2.49e+02 - ES count: 5
# Epoch 42 - Train loss: 58.7 - Val loss: 2.94e+02 - ES count: 6
# Epoch 43 - Train loss: 68.2 - Val loss: 6.15e+02 - ES count: 7
# Epoch 44 - Train loss: 56.3 - Val loss: 2.43e+02 - ES count: 0
# Epoch 45 - Train loss: 59.8 - Val loss: 2.58e+02 - ES count: 1
# Epoch 46 - Train loss: 51.2 - Val loss: 3.86e+02 - ES count: 2
# Epoch 47 - Train loss: 48.2 - Val loss: 6.6e+02 - ES count: 3
# Epoch 48 - Train loss: 94.9 - Val loss: 2.89e+02 - ES count: 4
# Epoch 49 - Train loss: 60.6 - Val loss: 3.12e+02 - ES count: 5
# Epoch 50 - Train loss: 61.5 - Val loss: 3.27e+02 - ES count: 6
# Epoch 51 - Train loss: 53.2 - Val loss: 3.23e+02 - ES count: 7
# Epoch 52 - Train loss: 59.1 - Val loss: 2.75e+02 - ES count: 8
# Epoch 53 - Train loss: 68.8 - Val loss: 2.78e+02 - ES count: 9
# Epoch 54 - Train loss: 54.3 - Val loss: 2.63e+02 - ES count: 10
# Epoch 55 - Train loss: 83.7 - Val loss: 3.3e+02 - ES count: 11
# Epoch 56 - Train loss: 54.2 - Val loss: 3.37e+02 - ES count: 12
# Epoch 57 - Train loss: 56.6 - Val loss: 3.83e+02 - ES count: 13
# Epoch 58 - Train loss: 50.4 - Val loss: 2.47e+02 - ES count: 14
# Epoch 59 - Train loss: 60.0 - Val loss: 3.02e+02 - ES count: 15
# Epoch 60 - Train loss: 53.1 - Val loss: 2.7e+02 - ES count: 16
# Epoch 61 - Train loss: 52.4 - Val loss: 3.54e+02 - ES count: 17
# Epoch 62 - Train loss: 49.2 - Val loss: 2.25e+02 - ES count: 0
# Epoch 63 - Train loss: 60.5 - Val loss: 2.88e+02 - ES count: 1
# Epoch 64 - Train loss: 54.6 - Val loss: 3.01e+02 - ES count: 2
# Epoch 65 - Train loss: 47.3 - Val loss: 2.47e+02 - ES count: 3
# Epoch 66 - Train loss: 48.0 - Val loss: 2.26e+02 - ES count: 4
# Epoch 67 - Train loss: 50.1 - Val loss: 2.56e+02 - ES count: 5
# Epoch 68 - Train loss: 52.9 - Val loss: 2.36e+02 - ES count: 6
# Epoch 69 - Train loss: 43.3 - Val loss: 2.57e+02 - ES count: 7
# Epoch 70 - Train loss: 43.4 - Val loss: 2.43e+02 - ES count: 8
# Epoch 71 - Train loss: 52.7 - Val loss: 2.37e+02 - ES count: 9
# Epoch 72 - Train loss: 49.9 - Val loss: 2.24e+02 - ES count: 0
# Epoch 73 - Train loss: 45.9 - Val loss: 2.71e+02 - ES count: 1
# Epoch 74 - Train loss: 41.2 - Val loss: 2.82e+02 - ES count: 2
# Epoch 75 - Train loss: 44.3 - Val loss: 2.49e+02 - ES count: 3
# Epoch 76 - Train loss: 51.3 - Val loss: 2.69e+02 - ES count: 4
# Epoch 77 - Train loss: 43.8 - Val loss: 2.62e+02 - ES count: 5
# Epoch 78 - Train loss: 44.0 - Val loss: 2.29e+02 - ES count: 6
# Epoch 79 - Train loss: 54.5 - Val loss: 2.46e+02 - ES count: 7
# Epoch 80 - Train loss: 42.7 - Val loss: 2.24e+02 - ES count: 8
# Epoch 81 - Train loss: 45.3 - Val loss: 2.98e+02 - ES count: 9
# Epoch 82 - Train loss: 61.7 - Val loss: 2.4e+02 - ES count: 10
# Epoch 83 - Train loss: 47.8 - Val loss: 2.35e+02 - ES count: 11
# Epoch 84 - Train loss: 47.1 - Val loss: 2.2e+02 - ES count: 0
# Epoch 85 - Train loss: 41.4 - Val loss: 2.34e+02 - ES count: 1
# Epoch 86 - Train loss: 40.3 - Val loss: 2.71e+02 - ES count: 2
# Epoch 87 - Train loss: 60.1 - Val loss: 2.58e+02 - ES count: 3
# Epoch 88 - Train loss: 43.3 - Val loss: 2.46e+02 - ES count: 4
# Epoch 89 - Train loss: 39.5 - Val loss: 2.44e+02 - ES count: 5
# Epoch 90 - Train loss: 42.2 - Val loss: 2.35e+02 - ES count: 6
# Epoch 91 - Train loss: 40.3 - Val loss: 2.29e+02 - ES count: 7
# Epoch 92 - Train loss: 45.0 - Val loss: 2.26e+02 - ES count: 8
# Epoch 93 - Train loss: 48.4 - Val loss: 2.13e+02 - ES count: 0
# Epoch 94 - Train loss: 41.0 - Val loss: 2.28e+02 - ES count: 1
# Epoch 95 - Train loss: 65.9 - Val loss: 3.91e+02 - ES count: 2
# Epoch 96 - Train loss: 39.9 - Val loss: 3.5e+02 - ES count: 3
# Epoch 97 - Train loss: 37.7 - Val loss: 2.16e+02 - ES count: 4
# Epoch 98 - Train loss: 45.3 - Val loss: 2.25e+02 - ES count: 5
# Epoch 99 - Train loss: 43.6 - Val loss: 2.5e+02 - ES count: 6
# Epoch 100 - Train loss: 40.6 - Val loss: 3.06e+02 - ES count: 7
# Epoch 101 - Train loss: 40.2 - Val loss: 2.81e+02 - ES count: 8
# Epoch 102 - Train loss: 43.3 - Val loss: 2.37e+02 - ES count: 9
# Epoch 103 - Train loss: 36.4 - Val loss: 3.22e+02 - ES count: 10
# Epoch 104 - Train loss: 41.7 - Val loss: 2.54e+02 - ES count: 11
# Epoch 105 - Train loss: 43.5 - Val loss: 3.05e+02 - ES count: 12
# Epoch 106 - Train loss: 37.3 - Val loss: 2.59e+02 - ES count: 13
# Epoch 107 - Train loss: 41.1 - Val loss: 2.36e+02 - ES count: 14
# Epoch 108 - Train loss: 42.3 - Val loss: 3.13e+02 - ES count: 15
# Epoch 109 - Train loss: 33.3 - Val loss: 2.12e+02 - ES count: 0
# Epoch 110 - Train loss: 39.1 - Val loss: 3.13e+02 - ES count: 1
# Epoch 111 - Train loss: 40.2 - Val loss: 2.59e+02 - ES count: 2
# Epoch 112 - Train loss: 40.5 - Val loss: 2.11e+02 - ES count: 0
# Epoch 113 - Train loss: 38.4 - Val loss: 2.43e+02 - ES count: 1
# Epoch 114 - Train loss: 50.6 - Val loss: 2.79e+02 - ES count: 2
# Epoch 115 - Train loss: 86.7 - Val loss: 6.52e+02 - ES count: 3
# Epoch 116 - Train loss: 75.4 - Val loss: 4.4e+02 - ES count: 4
# Epoch 117 - Train loss: 58.9 - Val loss: 3.76e+02 - ES count: 5
# Epoch 118 - Train loss: 56.3 - Val loss: 3.19e+02 - ES count: 6
# Epoch 119 - Train loss: 52.6 - Val loss: 3.28e+02 - ES count: 7
# Epoch 120 - Train loss: 58.0 - Val loss: 5.46e+02 - ES count: 8
# Epoch 121 - Train loss: 49.7 - Val loss: 2.85e+02 - ES count: 9
# Epoch 122 - Train loss: 76.2 - Val loss: 4.25e+02 - ES count: 10
# Epoch 123 - Train loss: 49.9 - Val loss: 2.85e+02 - ES count: 11
# Epoch 124 - Train loss: 51.5 - Val loss: 2.72e+02 - ES count: 12
# Epoch 125 - Train loss: 55.0 - Val loss: 2.62e+02 - ES count: 13
# Epoch 126 - Train loss: 42.6 - Val loss: 2.5e+02 - ES count: 14
# Epoch 127 - Train loss: 45.0 - Val loss: 2.63e+02 - ES count: 15
# Epoch 128 - Train loss: 49.7 - Val loss: 2.36e+02 - ES count: 16
# Epoch 129 - Train loss: 41.4 - Val loss: 2.54e+02 - ES count: 17
# Epoch 130 - Train loss: 53.6 - Val loss: 2.32e+02 - ES count: 18
# Epoch 131 - Train loss: 41.6 - Val loss: 3.1e+02 - ES count: 19
# Epoch 132 - Train loss: 48.5 - Val loss: 2.47e+02 - ES count: 20
# Epoch 133 - Train loss: 41.4 - Val loss: 3.18e+02 - ES count: 21
# Epoch 134 - Train loss: 43.7 - Val loss: 3.09e+02 - ES count: 22
# Epoch 135 - Train loss: 38.6 - Val loss: 2.63e+02 - ES count: 23
# Epoch 136 - Train loss: 33.3 - Val loss: 2.89e+02 - ES count: 24
# Epoch 137 - Train loss: 38.9 - Val loss: 2.37e+02 - ES count: 25
# Epoch 138 - Train loss: 39.4 - Val loss: 3.01e+02 - ES count: 26
# Epoch 139 - Train loss: 40.4 - Val loss: 2.42e+02 - ES count: 27
# Epoch 140 - Train loss: 34.4 - Val loss: 2.8e+02 - ES count: 28
# Epoch 141 - Train loss: 40.5 - Val loss: 2.27e+02 - ES count: 29
# Epoch 142 - Train loss: 48.4 - Val loss: 3.77e+02 - ES count: 30

# %%
base_save_path = project_dir / "src" / "outputs" / "visuals" / "serotype-nowcasts" / "raw" / "const-props"
N = len(sero_dataset.get_prop_vec("2020-01-01"))
sero_pnn_model = SimSero(M=M, D=D, T=T, Q=Q, N=N, hidden_units = [16, 8], conv_channels = [16, 1], embedding_dim = 10, dropout_probs = [0.15, 0.1], device="cpu")
sero_pnn_model.load_state_dict(torch.load(project_dir /"src" / "outputs" / "weights" / f"weights-SeroPNN"))

sero_pnn_train_samples, train_y_true = eval_sero_pnn(train_sero_pnn_dataset, sero_pnn_model, N=N)
plot_sero_pnn_preds(sero_pnn_train_samples, train_sero_pnn_dataset, N)

# crps = 0
# crps = sum([crps_ensemble(train_y_true[:,s], sero_pnn_train_samples[:,s,:]).mean() for s in range(N)])
# print(f"CRPS: {crps}")
sero_pnn_val_samples, val_y_true = eval_sero_pnn(val_sero_pnn_dataset, sero_pnn_model, N=N)
plot_sero_pnn_preds(sero_pnn_val_samples, val_sero_pnn_dataset, N)

# crps = 0
# crps = sum([crps_ensemble(val_y_true[:,s], sero_pnn_val_samples[:,s,:]).mean() for s in range(N)])
# print(f"CRPS: {crps}")
sero_pnn_test_samples, test_y_true = eval_sero_pnn(test_sero_pnn_dataset, sero_pnn_model, N=N)
plot_sero_pnn_preds(sero_pnn_test_samples, test_sero_pnn_dataset, N,  base_save_path)

# crps = 0
# crps = sum([crps_ensemble(test_y_true[:,s,:,0], sero_pnn_test_samples[:,s,:]) for s in range(N)])
# print(f"CRPS: {crps}")

# %%
# Simulate Data
# True counts * Constant sero prop vec * constant delay vec from average across world samples
# p_sero = np.array([0.5, 0.3, 0.2, 0.1])
p_sero = np.array([0.9, 0.0, 0.05, 0.05])
sero_all = ["DENV-1", "DENV-2", "DENV-3", "DENV-4"]



delays_df = pd.read_csv(project_dir / "data" / "transformed" / "DENG_delays.csv")
delays_df = delays_df.set_index("Collection date")
delays_df.index = pd.to_datetime(delays_df.index)

y_true = delays_df.sum(1)[:-2]
y_true_df = y_true.groupby(y_true.index.to_period("M")).sum()
y_true = np.array(y_true_df)
const = 10*np.ones_like(y_true)

denv_df = pd.read_csv(project_dir / "data" / "transformed" / "denv_df.csv")

denv_df = denv_df[denv_df['Delay'] < 60]

# If your original denv_df dates are datetime
denv_df['Collection date'] = pd.to_datetime(denv_df['Collection date'])

start_month = pd.to_datetime(delays_df.index.min())
end_month = pd.to_datetime(delays_df.index.max())

# Create a DataFrame of month start dates as datetime (not Period)
dates = pd.DataFrame({
    "Collection date": pd.date_range(start=start_month, end=end_month, freq='MS')
})

df = denv_df[denv_df['Sero'] == "DENV-1"] \
    .groupby(['Sero', 'Collection date', 'Delay']) \
    .size() \
    .reset_index(name='count')

df = df.pivot(index='Collection date', columns='Delay', values='count')

# Ensure df.index is datetime as well
df.index = pd.to_datetime(df.index)

p_delay = np.array(df.fillna(0).mean(0) / df.fillna(0).mean(0).sum())

p_sero = p_sero[:, np.newaxis, np.newaxis]   # shape (S,1,1)
const = const[np.newaxis, :, np.newaxis]  # shape (1,T,1)
p_delay = p_delay[np.newaxis, np.newaxis, :Q]  # shape (1,1,D)

# multiply to get (S,T,D)
sero_tensor = p_sero * const * p_delay
# sero_tensor = sero_tensor.round()
for s,sero in enumerate(sero_all):
    sero_df = pd.DataFrame(sero_tensor[s, :, :])
    sero_df.index = y_true_df.index
    sero_df.to_csv(project_dir / "data" / "model" / "sero_dfs" / f"{sero}.csv", index=True)
    print("Saving sero: ", sero)


# Create Serotype obj
sero_tensor = []
base_folder = project_dir / "data" / "model" / "sero_dfs"
files = [f for f in os.listdir(base_folder) if f.endswith('.csv')]
for file in files:
    file_path = os.path.join(base_folder, file)
    df = pd.read_csv(file_path)
    dates = df['Collection date']
    sero_df = df.drop(columns="Collection date")
    sero_tensor.append(sero_df)
sero_tensor = np.array(sero_tensor)

sero_dataset = SimulateSero(sero_tensor, dates, T=T, Q=Q, N=N, prop_vec=p_sero)



# Create count obj
delays_df = pd.read_csv(project_dir / "data" / "transformed" / "DENG_delays.csv")
delays_df['Collection date'] = pd.to_datetime(delays_df['Collection date'])

partial_count_dataset = PartialCountDataset(delays_df, D=D, M=M)
true_count_dataset = TrueCountDataset(delays_df)


# End of 2023 appears to have some incomplete data
if end_year == 2023:
    dates = list(pd.date_range(f"{start_year}-01-01",f"{end_year}-12-25", freq='D'))
else:
    dates = list(pd.date_range(f"{start_year}-01-01",f"{end_year}-12-31", freq='D'))
data_split_sizes = (np.array(data_split) * len(dates)).astype(int)

# Ensure dates line up fully, also removing 2023-12-31 as doesn't appear complete
data_split_sizes[-1] = len(dates) - data_split_sizes[:-1].sum()


train_dates = dates[:data_split_sizes[0]]
val_dates = dates[data_split_sizes[0]:data_split_sizes[0]+data_split_sizes[1]]
test_dates = dates[data_split_sizes[0]+data_split_sizes[1]:]


class SeroPNNDataset(Dataset):
    def __init__(self, partial_count_obj, true_count_obj, sero_obj, dates):
        self.partial_count_obj = partial_count_obj
        self.true_count_obj = true_count_obj
        self.sero_obj = sero_obj
        self.dates = dates
    
    def __len__(self):
        return len(self.dates)
    
    def __getitem__(self, index):
        date = self.dates[index]
        obs = self.partial_count_obj.get_obs(date)
        sero_obs = self.sero_obj.get_obs(date)
        prop_vec = self.sero_obj.get_prop_vec(date)
        y = self.true_count_obj.get_y_prop(date, prop_vec)
        dow = date.day_of_week
        return (obs, dow, sero_obs), y
    
set_seed(seed)
sero_props = pd.read_csv(project_dir / "data" / "transformed" / "sero_props.csv")


train_sero_pnn_dataset = SeroPNNDataset(partial_count_dataset, true_count_dataset, sero_dataset, train_dates)
val_sero_pnn_dataset = SeroPNNDataset(partial_count_dataset, true_count_dataset, sero_dataset, val_dates)
test_sero_pnn_dataset = SeroPNNDataset(partial_count_dataset, true_count_dataset,  sero_dataset, test_dates)

g = torch.Generator()
g.manual_seed(seed)

train_loader = DataLoader(train_sero_pnn_dataset, batch_size=32, shuffle=True, generator=g)
val_loader = DataLoader(val_sero_pnn_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_sero_pnn_dataset, batch_size=32, shuffle=False)
# Out:
# Saving sero:  DENV-1
# Saving sero:  DENV-2
# Saving sero:  DENV-3
# Saving sero:  DENV-4

# %%
N = len(sero_dataset.get_prop_vec("2020-01-01"))
sero_pnn_model = SimSero(M=M, D=D, T=T, Q=Q, N=N, hidden_units = [16, 8], conv_channels = [16, 1], embedding_dim = 10, dropout_probs = [0.15, 0.1], device="cpu")
sero_pnn_train = SeroTrain("SeroPNN(low const)", lr=0.0003, num_epochs=300)
sero_pnn_train.train_model(sero_pnn_model, train_loader, val_loader)
# Out:
# Epoch 1 - Train loss: 2.85e+03 - Val loss: 4.16e+04 - ES count: 0
# Epoch 2 - Train loss: 2.57e+03 - Val loss: 2.43e+04 - ES count: 0
# Epoch 3 - Train loss: 2.28e+03 - Val loss: 2.54e+04 - ES count: 1
# Epoch 4 - Train loss: 2.04e+03 - Val loss: 2.23e+04 - ES count: 0
# Epoch 5 - Train loss: 1.9e+03 - Val loss: 1.81e+04 - ES count: 0
# Epoch 6 - Train loss: 1.73e+03 - Val loss: 1.64e+04 - ES count: 0
# Epoch 7 - Train loss: 1.72e+03 - Val loss: 1.81e+04 - ES count: 1
# Epoch 8 - Train loss: 1.51e+03 - Val loss: 1.4e+04 - ES count: 0
# Epoch 9 - Train loss: 1.33e+03 - Val loss: 1.31e+04 - ES count: 0
# Epoch 10 - Train loss: 1.3e+03 - Val loss: 1.43e+04 - ES count: 1
# Epoch 11 - Train loss: 1.35e+03 - Val loss: 1.4e+04 - ES count: 2
# Epoch 12 - Train loss: 1.19e+03 - Val loss: 1.14e+04 - ES count: 0
# Epoch 13 - Train loss: 1.06e+03 - Val loss: 1.03e+04 - ES count: 0
# Epoch 14 - Train loss: 9.57e+02 - Val loss: 9.41e+03 - ES count: 0
# Epoch 15 - Train loss: 8.48e+02 - Val loss: 7.58e+03 - ES count: 0
# Epoch 16 - Train loss: 7.86e+02 - Val loss: 6.81e+03 - ES count: 0
# Epoch 17 - Train loss: 6.85e+02 - Val loss: 5.38e+03 - ES count: 0
# Epoch 18 - Train loss: 6.12e+02 - Val loss: 5.19e+03 - ES count: 0
# Epoch 19 - Train loss: 5.64e+02 - Val loss: 4.87e+03 - ES count: 0
# Epoch 20 - Train loss: 5.11e+02 - Val loss: 4.07e+03 - ES count: 0
# Epoch 21 - Train loss: 4.69e+02 - Val loss: 3.78e+03 - ES count: 0
# Epoch 22 - Train loss: 4.58e+02 - Val loss: 3.44e+03 - ES count: 0
# Epoch 23 - Train loss: 4.38e+02 - Val loss: 3.6e+03 - ES count: 1
# Epoch 24 - Train loss: 3.93e+02 - Val loss: 3.35e+03 - ES count: 0
# Epoch 25 - Train loss: 4.11e+02 - Val loss: 2.86e+03 - ES count: 0
# Epoch 26 - Train loss: 4.18e+02 - Val loss: 4.23e+03 - ES count: 1
# Epoch 27 - Train loss: 4.94e+02 - Val loss: 4.48e+03 - ES count: 2
# Epoch 28 - Train loss: 4.87e+02 - Val loss: 4.17e+03 - ES count: 3
# Epoch 29 - Train loss: 4.76e+02 - Val loss: 4e+03 - ES count: 4
# Epoch 30 - Train loss: 4.55e+02 - Val loss: 4.03e+03 - ES count: 5
# Epoch 31 - Train loss: 4.36e+02 - Val loss: 3.79e+03 - ES count: 6
# Epoch 32 - Train loss: 4.32e+02 - Val loss: 3.9e+03 - ES count: 7
# Epoch 33 - Train loss: 4.22e+02 - Val loss: 3.62e+03 - ES count: 8
# Epoch 34 - Train loss: 4.01e+02 - Val loss: 3.51e+03 - ES count: 9
# Epoch 35 - Train loss: 3.85e+02 - Val loss: 3.42e+03 - ES count: 10
# Epoch 36 - Train loss: 3.9e+02 - Val loss: 3.34e+03 - ES count: 11
# Epoch 37 - Train loss: 3.72e+02 - Val loss: 3.28e+03 - ES count: 12
# Epoch 38 - Train loss: 3.86e+02 - Val loss: 3.26e+03 - ES count: 13
# Epoch 39 - Train loss: 3.95e+02 - Val loss: 3.24e+03 - ES count: 14
# Epoch 40 - Train loss: 3.46e+02 - Val loss: 3.02e+03 - ES count: 15
# Epoch 41 - Train loss: 3.49e+02 - Val loss: 2.92e+03 - ES count: 16
# Epoch 42 - Train loss: 3.36e+02 - Val loss: 2.9e+03 - ES count: 17
# Epoch 43 - Train loss: 3.46e+02 - Val loss: 3.57e+03 - ES count: 18
# Epoch 44 - Train loss: 3.2e+02 - Val loss: 2.65e+03 - ES count: 0
# Epoch 45 - Train loss: 3.02e+02 - Val loss: 2.73e+03 - ES count: 1
# Epoch 46 - Train loss: 3.01e+02 - Val loss: 2.52e+03 - ES count: 0
# Epoch 47 - Train loss: 2.93e+02 - Val loss: 2.42e+03 - ES count: 0
# Epoch 48 - Train loss: 2.74e+02 - Val loss: 2.32e+03 - ES count: 0
# Epoch 49 - Train loss: 2.69e+02 - Val loss: 2.17e+03 - ES count: 0
# Epoch 50 - Train loss: 2.61e+02 - Val loss: 2.11e+03 - ES count: 0
# Epoch 51 - Train loss: 2.44e+02 - Val loss: 1.99e+03 - ES count: 0
# Epoch 52 - Train loss: 2.52e+02 - Val loss: 1.89e+03 - ES count: 0
# Epoch 53 - Train loss: 2.21e+02 - Val loss: 1.81e+03 - ES count: 0
# Epoch 54 - Train loss: 2.21e+02 - Val loss: 1.71e+03 - ES count: 0
# Epoch 55 - Train loss: 2.13e+02 - Val loss: 1.62e+03 - ES count: 0
# Epoch 56 - Train loss: 2.05e+02 - Val loss: 1.64e+03 - ES count: 1
# Epoch 57 - Train loss: 2.23e+02 - Val loss: 1.48e+03 - ES count: 0
# Epoch 58 - Train loss: 2.02e+02 - Val loss: 1.38e+03 - ES count: 0
# Epoch 59 - Train loss: 1.94e+02 - Val loss: 1.35e+03 - ES count: 0
# Epoch 60 - Train loss: 1.77e+02 - Val loss: 1.29e+03 - ES count: 0
# Epoch 61 - Train loss: 1.71e+02 - Val loss: 1.18e+03 - ES count: 0
# Epoch 62 - Train loss: 1.72e+02 - Val loss: 1.11e+03 - ES count: 0
# Epoch 63 - Train loss: 1.68e+02 - Val loss: 1.09e+03 - ES count: 0
# Epoch 64 - Train loss: 1.62e+02 - Val loss: 1.04e+03 - ES count: 0
# Epoch 65 - Train loss: 1.58e+02 - Val loss: 1.13e+03 - ES count: 1
# Epoch 66 - Train loss: 1.58e+02 - Val loss: 9.64e+02 - ES count: 0
# Epoch 67 - Train loss: 1.6e+02 - Val loss: 9.86e+02 - ES count: 1
# Epoch 68 - Train loss: 1.63e+02 - Val loss: 9.05e+02 - ES count: 0
# Epoch 69 - Train loss: 1.5e+02 - Val loss: 8.91e+02 - ES count: 0
# Epoch 70 - Train loss: 1.48e+02 - Val loss: 9.9e+02 - ES count: 1
# Epoch 71 - Train loss: 1.57e+02 - Val loss: 9.85e+02 - ES count: 2
# Epoch 72 - Train loss: 1.46e+02 - Val loss: 9.38e+02 - ES count: 3
# Epoch 73 - Train loss: 1.38e+02 - Val loss: 8.5e+02 - ES count: 0
# Epoch 74 - Train loss: 1.34e+02 - Val loss: 8.73e+02 - ES count: 1
# Epoch 75 - Train loss: 1.51e+02 - Val loss: 1.04e+03 - ES count: 2
# Epoch 76 - Train loss: 1.5e+02 - Val loss: 9.94e+02 - ES count: 3
# Epoch 77 - Train loss: 1.42e+02 - Val loss: 8.67e+02 - ES count: 4
# Epoch 78 - Train loss: 1.38e+02 - Val loss: 1.09e+03 - ES count: 5
# Epoch 79 - Train loss: 1.43e+02 - Val loss: 9.43e+02 - ES count: 6
# Epoch 80 - Train loss: 1.39e+02 - Val loss: 9.01e+02 - ES count: 7
# Epoch 81 - Train loss: 1.4e+02 - Val loss: 9.73e+02 - ES count: 8
# Epoch 82 - Train loss: 1.43e+02 - Val loss: 7.69e+02 - ES count: 0
# Epoch 83 - Train loss: 1.35e+02 - Val loss: 7.45e+02 - ES count: 0
# Epoch 84 - Train loss: 1.33e+02 - Val loss: 8.07e+02 - ES count: 1
# Epoch 85 - Train loss: 1.29e+02 - Val loss: 8.49e+02 - ES count: 2
# Epoch 86 - Train loss: 1.3e+02 - Val loss: 8.81e+02 - ES count: 3
# Epoch 87 - Train loss: 1.38e+02 - Val loss: 9.05e+02 - ES count: 4
# Epoch 88 - Train loss: 1.41e+02 - Val loss: 8.2e+02 - ES count: 5
# Epoch 89 - Train loss: 1.25e+02 - Val loss: 8.58e+02 - ES count: 6
# Epoch 90 - Train loss: 1.19e+02 - Val loss: 7.6e+02 - ES count: 7
# Epoch 91 - Train loss: 1.31e+02 - Val loss: 7.75e+02 - ES count: 8
# Epoch 92 - Train loss: 1.37e+02 - Val loss: 1.37e+03 - ES count: 9
# Epoch 93 - Train loss: 1.49e+02 - Val loss: 1.09e+03 - ES count: 10
# Epoch 94 - Train loss: 1.28e+02 - Val loss: 8.67e+02 - ES count: 11
# Epoch 95 - Train loss: 1.6e+02 - Val loss: 1.16e+03 - ES count: 12
# Epoch 96 - Train loss: 1.15e+02 - Val loss: 8.76e+02 - ES count: 13
# Epoch 97 - Train loss: 1.38e+02 - Val loss: 1.09e+03 - ES count: 14
# Epoch 98 - Train loss: 1.22e+02 - Val loss: 9.83e+02 - ES count: 15
# Epoch 99 - Train loss: 1.25e+02 - Val loss: 8.34e+02 - ES count: 16
# Epoch 100 - Train loss: 1.09e+02 - Val loss: 8.06e+02 - ES count: 17
# Epoch 101 - Train loss: 1.14e+02 - Val loss: 7.72e+02 - ES count: 18
# Epoch 102 - Train loss: 1.06e+02 - Val loss: 7.47e+02 - ES count: 19
# Epoch 103 - Train loss: 1.1e+02 - Val loss: 7.97e+02 - ES count: 20
# Epoch 104 - Train loss: 1.09e+02 - Val loss: 7.58e+02 - ES count: 21
# Epoch 105 - Train loss: 1.01e+02 - Val loss: 8.21e+02 - ES count: 22
# Epoch 106 - Train loss: 1.02e+02 - Val loss: 7.53e+02 - ES count: 23
# Epoch 107 - Train loss: 1.13e+02 - Val loss: 7.45e+02 - ES count: 24
# Epoch 108 - Train loss: 1.07e+02 - Val loss: 8.5e+02 - ES count: 25
# Epoch 109 - Train loss: 1.03e+02 - Val loss: 6.9e+02 - ES count: 0
# Epoch 110 - Train loss: 1.02e+02 - Val loss: 7.7e+02 - ES count: 1
# Epoch 111 - Train loss: 1.02e+02 - Val loss: 7.02e+02 - ES count: 2
# Epoch 112 - Train loss: 98.2 - Val loss: 6.48e+02 - ES count: 0
# Epoch 113 - Train loss: 94.5 - Val loss: 6.51e+02 - ES count: 1
# Epoch 114 - Train loss: 96.2 - Val loss: 7.89e+02 - ES count: 2
# Epoch 115 - Train loss: 99.0 - Val loss: 6.84e+02 - ES count: 3
# Epoch 116 - Train loss: 1.04e+02 - Val loss: 7.52e+02 - ES count: 4
# Epoch 117 - Train loss: 96.6 - Val loss: 6.35e+02 - ES count: 0
# Epoch 118 - Train loss: 87.6 - Val loss: 6.61e+02 - ES count: 1
# Epoch 119 - Train loss: 97.0 - Val loss: 6.62e+02 - ES count: 2
# Epoch 120 - Train loss: 1e+02 - Val loss: 7.28e+02 - ES count: 3
# Epoch 121 - Train loss: 1.01e+02 - Val loss: 6.14e+02 - ES count: 0
# Epoch 122 - Train loss: 1.29e+02 - Val loss: 7.22e+02 - ES count: 1
# Epoch 123 - Train loss: 86.5 - Val loss: 6.55e+02 - ES count: 2
# Epoch 124 - Train loss: 91.2 - Val loss: 6.73e+02 - ES count: 3
# Epoch 125 - Train loss: 90.7 - Val loss: 6.53e+02 - ES count: 4
# Epoch 126 - Train loss: 82.7 - Val loss: 5.73e+02 - ES count: 0
# Epoch 127 - Train loss: 85.1 - Val loss: 6.1e+02 - ES count: 1
# Epoch 128 - Train loss: 90.0 - Val loss: 5.61e+02 - ES count: 0
# Epoch 129 - Train loss: 82.3 - Val loss: 5.3e+02 - ES count: 0
# Epoch 130 - Train loss: 82.6 - Val loss: 6.34e+02 - ES count: 1
# Epoch 131 - Train loss: 96.9 - Val loss: 6e+02 - ES count: 2
# Epoch 132 - Train loss: 80.8 - Val loss: 7.01e+02 - ES count: 3
# Epoch 133 - Train loss: 89.5 - Val loss: 5.71e+02 - ES count: 4
# Epoch 134 - Train loss: 77.3 - Val loss: 6.23e+02 - ES count: 5
# Epoch 135 - Train loss: 81.7 - Val loss: 9.67e+02 - ES count: 6
# Epoch 136 - Train loss: 81.5 - Val loss: 6.39e+02 - ES count: 7
# Epoch 137 - Train loss: 77.2 - Val loss: 5.49e+02 - ES count: 8
# Epoch 138 - Train loss: 80.1 - Val loss: 5.77e+02 - ES count: 9
# Epoch 139 - Train loss: 72.9 - Val loss: 5.68e+02 - ES count: 10
# Epoch 140 - Train loss: 1.22e+02 - Val loss: 9.07e+02 - ES count: 11
# Epoch 141 - Train loss: 96.0 - Val loss: 6.32e+02 - ES count: 12
# Epoch 142 - Train loss: 90.8 - Val loss: 6.78e+02 - ES count: 13
# Epoch 143 - Train loss: 78.8 - Val loss: 6.39e+02 - ES count: 14
# Epoch 144 - Train loss: 80.0 - Val loss: 5.01e+02 - ES count: 0
# Epoch 145 - Train loss: 71.0 - Val loss: 5.19e+02 - ES count: 1
# Epoch 146 - Train loss: 71.1 - Val loss: 5.18e+02 - ES count: 2
# Epoch 147 - Train loss: 72.2 - Val loss: 5.65e+02 - ES count: 3
# Epoch 148 - Train loss: 70.1 - Val loss: 5.11e+02 - ES count: 4
# Epoch 149 - Train loss: 68.7 - Val loss: 5.08e+02 - ES count: 5
# Epoch 150 - Train loss: 65.4 - Val loss: 4.77e+02 - ES count: 0
# Epoch 151 - Train loss: 67.2 - Val loss: 5.1e+02 - ES count: 1
# Epoch 152 - Train loss: 64.5 - Val loss: 4.86e+02 - ES count: 2
# Epoch 153 - Train loss: 63.3 - Val loss: 4.57e+02 - ES count: 0
# Epoch 154 - Train loss: 65.8 - Val loss: 4.91e+02 - ES count: 1
# Epoch 155 - Train loss: 65.8 - Val loss: 4.51e+02 - ES count: 0
# Epoch 156 - Train loss: 59.6 - Val loss: 4.7e+02 - ES count: 1
# Epoch 157 - Train loss: 59.5 - Val loss: 4.51e+02 - ES count: 2
# Epoch 158 - Train loss: 58.1 - Val loss: 4.3e+02 - ES count: 0
# Epoch 159 - Train loss: 59.2 - Val loss: 4.5e+02 - ES count: 1
# Epoch 160 - Train loss: 57.0 - Val loss: 4.26e+02 - ES count: 0
# Epoch 161 - Train loss: 66.6 - Val loss: 1.15e+03 - ES count: 1
# Epoch 162 - Train loss: 1.14e+02 - Val loss: 9.99e+02 - ES count: 2
# Epoch 163 - Train loss: 80.1 - Val loss: 6.66e+02 - ES count: 3
# Epoch 164 - Train loss: 55.4 - Val loss: 4.3e+02 - ES count: 4
# Epoch 165 - Train loss: 52.9 - Val loss: 4.21e+02 - ES count: 0
# Epoch 166 - Train loss: 53.5 - Val loss: 4e+02 - ES count: 0
# Epoch 167 - Train loss: 51.1 - Val loss: 4.05e+02 - ES count: 1
# Epoch 168 - Train loss: 48.6 - Val loss: 3.95e+02 - ES count: 0
# Epoch 169 - Train loss: 48.4 - Val loss: 3.9e+02 - ES count: 0
# Epoch 170 - Train loss: 49.8 - Val loss: 3.75e+02 - ES count: 0
# Epoch 171 - Train loss: 46.0 - Val loss: 3.73e+02 - ES count: 0
# Epoch 172 - Train loss: 55.3 - Val loss: 3.82e+02 - ES count: 1
# Epoch 173 - Train loss: 46.7 - Val loss: 3.71e+02 - ES count: 0
# Epoch 174 - Train loss: 47.5 - Val loss: 4.97e+02 - ES count: 1
# Epoch 175 - Train loss: 40.0 - Val loss: 3.42e+02 - ES count: 0
# Epoch 176 - Train loss: 41.9 - Val loss: 3.83e+02 - ES count: 1
# Epoch 177 - Train loss: 41.6 - Val loss: 3.36e+02 - ES count: 0
# Epoch 178 - Train loss: 41.2 - Val loss: 3.22e+02 - ES count: 0
# Epoch 179 - Train loss: 43.3 - Val loss: 3.26e+02 - ES count: 1
# Epoch 180 - Train loss: 42.6 - Val loss: 3.64e+02 - ES count: 2
# Epoch 181 - Train loss: 40.8 - Val loss: 3.28e+02 - ES count: 3
# Epoch 182 - Train loss: 39.1 - Val loss: 3.11e+02 - ES count: 0
# Epoch 183 - Train loss: 38.1 - Val loss: 3.17e+02 - ES count: 1
# Epoch 184 - Train loss: 39.9 - Val loss: 3.97e+02 - ES count: 2
# Epoch 185 - Train loss: 40.4 - Val loss: 3.25e+02 - ES count: 3
# Epoch 186 - Train loss: 34.4 - Val loss: 3.18e+02 - ES count: 4
# Epoch 187 - Train loss: 40.0 - Val loss: 3.01e+02 - ES count: 0
# Epoch 188 - Train loss: 41.3 - Val loss: 3.26e+02 - ES count: 1
# Epoch 189 - Train loss: 36.0 - Val loss: 2.84e+02 - ES count: 0
# Epoch 190 - Train loss: 33.8 - Val loss: 3.78e+02 - ES count: 1
# Epoch 191 - Train loss: 35.6 - Val loss: 2.73e+02 - ES count: 0
# Epoch 192 - Train loss: 33.7 - Val loss: 2.71e+02 - ES count: 0
# Epoch 193 - Train loss: 33.0 - Val loss: 2.95e+02 - ES count: 1
# Epoch 194 - Train loss: 31.2 - Val loss: 2.57e+02 - ES count: 0
# Epoch 195 - Train loss: 31.5 - Val loss: 2.58e+02 - ES count: 1
# Epoch 196 - Train loss: 29.3 - Val loss: 2.63e+02 - ES count: 2
# Epoch 197 - Train loss: 32.0 - Val loss: 2.72e+02 - ES count: 3
# Epoch 198 - Train loss: 28.1 - Val loss: 2.44e+02 - ES count: 0
# Epoch 199 - Train loss: 29.8 - Val loss: 2.75e+02 - ES count: 1
# Epoch 200 - Train loss: 30.1 - Val loss: 2.52e+02 - ES count: 2
# Epoch 201 - Train loss: 30.6 - Val loss: 2.46e+02 - ES count: 3
# Epoch 202 - Train loss: 29.1 - Val loss: 2.5e+02 - ES count: 4
# Epoch 203 - Train loss: 29.3 - Val loss: 2.37e+02 - ES count: 0
# Epoch 204 - Train loss: 26.3 - Val loss: 2.48e+02 - ES count: 1
# Epoch 205 - Train loss: 26.8 - Val loss: 2.4e+02 - ES count: 2
# Epoch 206 - Train loss: 31.4 - Val loss: 2.68e+02 - ES count: 3
# Epoch 207 - Train loss: 27.3 - Val loss: 2.36e+02 - ES count: 0
# Epoch 208 - Train loss: 24.9 - Val loss: 2.35e+02 - ES count: 0
# Epoch 209 - Train loss: 26.7 - Val loss: 2.53e+02 - ES count: 1
# Epoch 210 - Train loss: 24.4 - Val loss: 2.22e+02 - ES count: 0
# Epoch 211 - Train loss: 25.5 - Val loss: 2.28e+02 - ES count: 1
# Epoch 212 - Train loss: 23.2 - Val loss: 2.13e+02 - ES count: 0
# Epoch 213 - Train loss: 23.4 - Val loss: 2.4e+02 - ES count: 1
# Epoch 214 - Train loss: 24.5 - Val loss: 2.03e+02 - ES count: 0
# Epoch 215 - Train loss: 22.4 - Val loss: 2.24e+02 - ES count: 1
# Epoch 216 - Train loss: 21.6 - Val loss: 2e+02 - ES count: 0
# Epoch 217 - Train loss: 21.8 - Val loss: 2.02e+02 - ES count: 1
# Epoch 218 - Train loss: 22.3 - Val loss: 2.01e+02 - ES count: 2
# Epoch 219 - Train loss: 21.0 - Val loss: 2.15e+02 - ES count: 3
# Epoch 220 - Train loss: 20.4 - Val loss: 2.04e+02 - ES count: 4
# Epoch 221 - Train loss: 25.6 - Val loss: 2.28e+02 - ES count: 5
# Epoch 222 - Train loss: 20.3 - Val loss: 1.93e+02 - ES count: 0
# Epoch 223 - Train loss: 22.8 - Val loss: 1.95e+02 - ES count: 1
# Epoch 224 - Train loss: 19.6 - Val loss: 2.21e+02 - ES count: 2
# Epoch 225 - Train loss: 19.0 - Val loss: 2e+02 - ES count: 3
# Epoch 226 - Train loss: 20.1 - Val loss: 1.86e+02 - ES count: 0
# Epoch 227 - Train loss: 18.8 - Val loss: 1.84e+02 - ES count: 0
# Epoch 228 - Train loss: 18.8 - Val loss: 1.82e+02 - ES count: 0
# Epoch 229 - Train loss: 19.1 - Val loss: 2e+02 - ES count: 1
# Epoch 230 - Train loss: 24.4 - Val loss: 1.72e+02 - ES count: 0
# Epoch 231 - Train loss: 21.8 - Val loss: 1.77e+02 - ES count: 1
# Epoch 232 - Train loss: 19.7 - Val loss: 1.74e+02 - ES count: 2
# Epoch 233 - Train loss: 29.2 - Val loss: 3.79e+02 - ES count: 3
# Epoch 234 - Train loss: 20.2 - Val loss: 1.77e+02 - ES count: 4
# Epoch 235 - Train loss: 18.5 - Val loss: 2.46e+02 - ES count: 5
# Epoch 236 - Train loss: 20.1 - Val loss: 1.71e+02 - ES count: 0
# Epoch 237 - Train loss: 17.9 - Val loss: 1.75e+02 - ES count: 1
# Epoch 238 - Train loss: 17.1 - Val loss: 1.7e+02 - ES count: 0
# Epoch 239 - Train loss: 16.1 - Val loss: 1.62e+02 - ES count: 0
# Epoch 240 - Train loss: 17.0 - Val loss: 1.55e+02 - ES count: 0
# Epoch 241 - Train loss: 16.8 - Val loss: 1.57e+02 - ES count: 1
# Epoch 242 - Train loss: 37.2 - Val loss: 3.05e+02 - ES count: 2
# Epoch 243 - Train loss: 17.2 - Val loss: 1.62e+02 - ES count: 3
# Epoch 244 - Train loss: 17.1 - Val loss: 1.59e+02 - ES count: 4
# Epoch 245 - Train loss: 16.3 - Val loss: 1.65e+02 - ES count: 5
# Epoch 246 - Train loss: 16.4 - Val loss: 1.56e+02 - ES count: 6
# Epoch 247 - Train loss: 16.2 - Val loss: 1.65e+02 - ES count: 7
# Epoch 248 - Train loss: 14.7 - Val loss: 1.6e+02 - ES count: 8
# Epoch 249 - Train loss: 15.6 - Val loss: 1.53e+02 - ES count: 0
# Epoch 250 - Train loss: 14.8 - Val loss: 1.44e+02 - ES count: 0
# Epoch 251 - Train loss: 16.0 - Val loss: 1.46e+02 - ES count: 1
# Epoch 252 - Train loss: 14.5 - Val loss: 1.41e+02 - ES count: 0
# Epoch 253 - Train loss: 15.4 - Val loss: 1.41e+02 - ES count: 0
# Epoch 254 - Train loss: 17.0 - Val loss: 1.49e+02 - ES count: 1
# Epoch 255 - Train loss: 13.6 - Val loss: 1.42e+02 - ES count: 2
# Epoch 256 - Train loss: 14.3 - Val loss: 1.4e+02 - ES count: 0
# Epoch 257 - Train loss: 14.8 - Val loss: 1.48e+02 - ES count: 1
# Epoch 258 - Train loss: 15.1 - Val loss: 1.42e+02 - ES count: 2
# Epoch 259 - Train loss: 13.7 - Val loss: 1.45e+02 - ES count: 3
# Epoch 260 - Train loss: 13.7 - Val loss: 1.37e+02 - ES count: 0
# Epoch 261 - Train loss: 13.3 - Val loss: 1.34e+02 - ES count: 0
# Epoch 262 - Train loss: 13.1 - Val loss: 1.41e+02 - ES count: 1
# Epoch 263 - Train loss: 13.4 - Val loss: 1.29e+02 - ES count: 0
# Epoch 264 - Train loss: 12.6 - Val loss: 1.29e+02 - ES count: 1
# Epoch 265 - Train loss: 12.6 - Val loss: 1.28e+02 - ES count: 0
# Epoch 266 - Train loss: 12.2 - Val loss: 1.25e+02 - ES count: 0
# Epoch 267 - Train loss: 13.1 - Val loss: 1.31e+02 - ES count: 1
# Epoch 268 - Train loss: 12.6 - Val loss: 1.27e+02 - ES count: 2
# Epoch 269 - Train loss: 13.0 - Val loss: 1.28e+02 - ES count: 3
# Epoch 270 - Train loss: 12.5 - Val loss: 1.29e+02 - ES count: 4
# Epoch 271 - Train loss: 16.3 - Val loss: 1.51e+02 - ES count: 5
# Epoch 272 - Train loss: 13.0 - Val loss: 1.31e+02 - ES count: 6
# Epoch 273 - Train loss: 12.6 - Val loss: 1.23e+02 - ES count: 0
# Epoch 274 - Train loss: 11.8 - Val loss: 1.19e+02 - ES count: 0
# Epoch 275 - Train loss: 11.9 - Val loss: 1.19e+02 - ES count: 0
# Epoch 276 - Train loss: 11.6 - Val loss: 1.18e+02 - ES count: 0
# Epoch 277 - Train loss: 11.3 - Val loss: 1.18e+02 - ES count: 0
# Epoch 278 - Train loss: 11.1 - Val loss: 1.22e+02 - ES count: 1
# Epoch 279 - Train loss: 11.1 - Val loss: 1.17e+02 - ES count: 0
# Epoch 280 - Train loss: 11.5 - Val loss: 1.18e+02 - ES count: 1
# Epoch 281 - Train loss: 11.2 - Val loss: 1.15e+02 - ES count: 0
# Epoch 282 - Train loss: 13.9 - Val loss: 1.31e+02 - ES count: 1
# Epoch 283 - Train loss: 10.6 - Val loss: 1.16e+02 - ES count: 2
# Epoch 284 - Train loss: 10.7 - Val loss: 1.11e+02 - ES count: 0
# Epoch 285 - Train loss: 11.5 - Val loss: 1.12e+02 - ES count: 1
# Epoch 286 - Train loss: 10.6 - Val loss: 1.13e+02 - ES count: 2
# Epoch 287 - Train loss: 10.2 - Val loss: 1.14e+02 - ES count: 3
# Epoch 288 - Train loss: 10.5 - Val loss: 1.19e+02 - ES count: 4
# Epoch 289 - Train loss: 10.1 - Val loss: 1.11e+02 - ES count: 5
# Epoch 290 - Train loss: 10.8 - Val loss: 1.1e+02 - ES count: 0
# Epoch 291 - Train loss: 10.9 - Val loss: 1.1e+02 - ES count: 0
# Epoch 292 - Train loss: 12.6 - Val loss: 1.14e+02 - ES count: 1
# Epoch 293 - Train loss: 10.0 - Val loss: 1.07e+02 - ES count: 0
# Epoch 294 - Train loss: 10.1 - Val loss: 1.07e+02 - ES count: 1
# Epoch 295 - Train loss: 10.2 - Val loss: 1.07e+02 - ES count: 2
# Epoch 296 - Train loss: 9.78 - Val loss: 1.06e+02 - ES count: 0
# Epoch 297 - Train loss: 10.1 - Val loss: 1.03e+02 - ES count: 0
# Epoch 298 - Train loss: 9.83 - Val loss: 1.06e+02 - ES count: 1
# Epoch 299 - Train loss: 9.81 - Val loss: 1.02e+02 - ES count: 0
# Epoch 300 - Train loss: 10.6 - Val loss: 1.03e+02 - ES count: 1

# %%
base_save_path = project_dir / "src" / "outputs" / "visuals" / "serotype-nowcasts" / "raw" / "low-const-props"

N = len(sero_dataset.get_prop_vec("2020-01-01"))
sero_pnn_model = SimSero(M=M, D=D, T=T, Q=Q, N=N, hidden_units = [16, 8], conv_channels = [16, 1], embedding_dim = 10, dropout_probs = [0.15, 0.1], device="cpu")
sero_pnn_model.load_state_dict(torch.load(project_dir /"src" / "outputs" / "weights" / f"weights-SeroPNN(low const)"))

sero_pnn_train_samples, train_y_true = eval_sero_pnn(train_sero_pnn_dataset, sero_pnn_model, N=N)
plot_sero_pnn_preds(sero_pnn_train_samples, train_sero_pnn_dataset, N)

# crps = 0
# crps = sum([crps_ensemble(train_y_true[:,s], sero_pnn_train_samples[:,s,:]).mean() for s in range(N)])
# print(f"CRPS: {crps}")
sero_pnn_val_samples, val_y_true = eval_sero_pnn(val_sero_pnn_dataset, sero_pnn_model, N=N)
plot_sero_pnn_preds(sero_pnn_val_samples, val_sero_pnn_dataset, N)

# crps = 0
# crps = sum([crps_ensemble(val_y_true[:,s], sero_pnn_val_samples[:,s,:]).mean() for s in range(N)])
# print(f"CRPS: {crps}")
sero_pnn_test_samples, test_y_true = eval_sero_pnn(test_sero_pnn_dataset, sero_pnn_model, N=N)
plot_sero_pnn_preds(sero_pnn_test_samples, test_sero_pnn_dataset, N, base_save_path)

# crps = 0
# crps = sum([crps_ensemble(test_y_true[:,s,:,0], sero_pnn_test_samples[:,s,:]) for s in range(N)])
# print(f"CRPS: {crps}")
