# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os
import sys
import torch
from torch.utils.data import DataLoader, Dataset
from properscoring import crps_ensemble
import random
from scipy.stats import nbinom


sys.path.append(os.path.abspath('../src'))
project_dir = Path.cwd().parent

from data_tools.data_utils import SeroDataset, PartialCountDataset, TrueCountDataset
from model_tools.train_utils import BaseTrain, SparsePropTrain, SeroTrain
from model_tools.models import NowcastPNN, PropPNN, SparsePropPNN, SeroPNN
from model_tools.evaluation import eval_pnn, eval_prop_pnn, eval_sparse_prop_pnn, eval_sero_pnn, plot_pnn_preds, plot_prop_pnn_preds, plot_sero_pnn_preds
D = 40
M = 50
T = 15
period = "M"

start_year = 2018
end_year = 2022
data_split = [0.6, 0.2, 0.2]
seed = 123

# 123, 2019, 2023, 15

def set_seed(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.use_deterministic_algorithms(True)

def compute_pica(y_true, y_pred, alpha=0.05):

    lower = np.quantile(y_pred, alpha / 2, axis=1)
    upper = np.quantile(y_pred, 1 - alpha / 2, axis=1)
    within_interval = (y_true >= lower) & (y_true <= upper)
    empirical_coverage = np.mean(within_interval)
    expected_coverage = 1 - alpha
    return np.abs(empirical_coverage - expected_coverage)

# %%
# Create count obj
delays_df = pd.read_csv(project_dir / "data" / "transformed" / "DENG_delays.csv")
delays_df['Collection date'] = pd.to_datetime(delays_df['Collection date'])

partial_count_dataset = PartialCountDataset(delays_df, D=D, M=M)
true_count_dataset = TrueCountDataset(delays_df)

# End of 2023 appears to have some incomplete data
if end_year == 2023:
    dates = list(pd.date_range(f"{start_year}-01-01",f"{end_year}-12-25", freq='D'))
else:
    dates = list(pd.date_range(f"{start_year}-01-01",f"{end_year}-12-31", freq='D'))
data_split_sizes = (np.array(data_split) * len(dates)).astype(int)

# Ensure dates line up fully, also removing 2023-12-31 as doesn't appear complete
data_split_sizes[-1] = len(dates) - data_split_sizes[:-1].sum()


train_dates = dates[:data_split_sizes[0]]
val_dates = dates[data_split_sizes[0]:data_split_sizes[0]+data_split_sizes[1]]
test_dates = dates[data_split_sizes[0]+data_split_sizes[1]:]

# %%
class PropPNNDataset(Dataset):
    def __init__(self, partial_count_obj, true_count_obj, dates):
        self.partial_count_obj = partial_count_obj
        self.true_count_obj = true_count_obj
        self.dates = dates
    
    def __len__(self):
        return len(self.dates)
    
    def __getitem__(self, index):
        date = self.dates[index]
        obs = self.partial_count_obj.get_obs(date)
        z = self.true_count_obj.get_z(date)
        dow = date.day_of_week
        return (obs, dow), z

set_seed(seed)
train_prop_pnn_dataset = PropPNNDataset(partial_count_dataset, true_count_dataset, train_dates)
val_prop_pnn_dataset = PropPNNDataset(partial_count_dataset, true_count_dataset, val_dates)
test_prop_pnn_dataset = PropPNNDataset(partial_count_dataset, true_count_dataset, test_dates)

g = torch.Generator()
g.manual_seed(seed)

train_loader = DataLoader(train_prop_pnn_dataset, batch_size=32, shuffle=True, generator=g)
val_loader = DataLoader(val_prop_pnn_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_prop_pnn_dataset, batch_size=32, shuffle=False)

# %%
prop_pnn_model = PropPNN(M=M, D=D, hidden_units = [16, 8], conv_channels = [16, 1], embedding_dim = 10, dropout_probs = [0.15, 0.1], device="cpu")
prop_pnn_train = BaseTrain("PropPNN")
prop_pnn_train.train_model(prop_pnn_model, train_loader, val_loader)
# Out:
# Epoch 1 - Train loss: 8.08e+03 - Val loss: 7.95e+04 - ES count: 0
# Epoch 2 - Train loss: 7.23e+03 - Val loss: 6.79e+04 - ES count: 0
# Epoch 3 - Train loss: 5.8e+03 - Val loss: 4.93e+04 - ES count: 0
# Epoch 4 - Train loss: 4.65e+03 - Val loss: 4.63e+04 - ES count: 0
# Epoch 5 - Train loss: 4.62e+03 - Val loss: 4.25e+04 - ES count: 0
# Epoch 6 - Train loss: 4.18e+03 - Val loss: 3.46e+04 - ES count: 0
# Epoch 7 - Train loss: 4.02e+03 - Val loss: 3.37e+04 - ES count: 0
# Epoch 8 - Train loss: 3.58e+03 - Val loss: 3.18e+04 - ES count: 0
# Epoch 9 - Train loss: 3.58e+03 - Val loss: 2.66e+04 - ES count: 0
# Epoch 10 - Train loss: 3.14e+03 - Val loss: 2.68e+04 - ES count: 1
# Epoch 11 - Train loss: 3.42e+03 - Val loss: 2.69e+04 - ES count: 2
# Epoch 12 - Train loss: 3.13e+03 - Val loss: 2.28e+04 - ES count: 0
# Epoch 13 - Train loss: 2.77e+03 - Val loss: 2.27e+04 - ES count: 0
# Epoch 14 - Train loss: 2.74e+03 - Val loss: 2.04e+04 - ES count: 0
# Epoch 15 - Train loss: 2.8e+03 - Val loss: 1.71e+04 - ES count: 0
# Epoch 16 - Train loss: 2.58e+03 - Val loss: 1.89e+04 - ES count: 1
# Epoch 17 - Train loss: 2.46e+03 - Val loss: 2.28e+04 - ES count: 2
# Epoch 18 - Train loss: 2.49e+03 - Val loss: 1.57e+04 - ES count: 0
# Epoch 19 - Train loss: 2.29e+03 - Val loss: 1.92e+04 - ES count: 1
# Epoch 20 - Train loss: 2.25e+03 - Val loss: 1.66e+04 - ES count: 2
# Epoch 21 - Train loss: 2.07e+03 - Val loss: 1.9e+04 - ES count: 3
# Epoch 22 - Train loss: 1.9e+03 - Val loss: 1.52e+04 - ES count: 0
# Epoch 23 - Train loss: 1.96e+03 - Val loss: 1.3e+04 - ES count: 0
# Epoch 24 - Train loss: 1.85e+03 - Val loss: 1.52e+04 - ES count: 1
# Epoch 25 - Train loss: 1.89e+03 - Val loss: 1.49e+04 - ES count: 2
# Epoch 26 - Train loss: 1.79e+03 - Val loss: 1.23e+04 - ES count: 0
# Epoch 27 - Train loss: 1.84e+03 - Val loss: 1.1e+04 - ES count: 0
# Epoch 28 - Train loss: 1.75e+03 - Val loss: 1.26e+04 - ES count: 1
# Epoch 29 - Train loss: 1.77e+03 - Val loss: 1.2e+04 - ES count: 2
# Epoch 30 - Train loss: 1.76e+03 - Val loss: 1.07e+04 - ES count: 0
# Epoch 31 - Train loss: 1.64e+03 - Val loss: 1.18e+04 - ES count: 1
# Epoch 32 - Train loss: 1.62e+03 - Val loss: 1.15e+04 - ES count: 2
# Epoch 33 - Train loss: 1.42e+03 - Val loss: 9.89e+03 - ES count: 0
# Epoch 34 - Train loss: 1.66e+03 - Val loss: 1.14e+04 - ES count: 1
# Epoch 35 - Train loss: 1.44e+03 - Val loss: 8.91e+03 - ES count: 0
# Epoch 36 - Train loss: 1.58e+03 - Val loss: 8.6e+03 - ES count: 0
# Epoch 37 - Train loss: 1.41e+03 - Val loss: 1.06e+04 - ES count: 1
# Epoch 38 - Train loss: 1.42e+03 - Val loss: 9.23e+03 - ES count: 2
# Epoch 39 - Train loss: 1.33e+03 - Val loss: 7.33e+03 - ES count: 0
# Epoch 40 - Train loss: 1.41e+03 - Val loss: 8.49e+03 - ES count: 1
# Epoch 41 - Train loss: 1.4e+03 - Val loss: 8.49e+03 - ES count: 2
# Epoch 42 - Train loss: 1.34e+03 - Val loss: 7.86e+03 - ES count: 3
# Epoch 43 - Train loss: 1.35e+03 - Val loss: 6.85e+03 - ES count: 0
# Epoch 44 - Train loss: 1.28e+03 - Val loss: 9.31e+03 - ES count: 1
# Epoch 45 - Train loss: 1.28e+03 - Val loss: 9.68e+03 - ES count: 2
# Epoch 46 - Train loss: 1.27e+03 - Val loss: 8.71e+03 - ES count: 3
# Epoch 47 - Train loss: 1.16e+03 - Val loss: 7.95e+03 - ES count: 4
# Epoch 48 - Train loss: 1.25e+03 - Val loss: 8.58e+03 - ES count: 5
# Epoch 49 - Train loss: 1.17e+03 - Val loss: 8.41e+03 - ES count: 6
# Epoch 50 - Train loss: 1.23e+03 - Val loss: 8.23e+03 - ES count: 7
# Epoch 51 - Train loss: 1.25e+03 - Val loss: 7.79e+03 - ES count: 8
# Epoch 52 - Train loss: 1.18e+03 - Val loss: 7.32e+03 - ES count: 9
# Epoch 53 - Train loss: 1.29e+03 - Val loss: 6.85e+03 - ES count: 10
# Epoch 54 - Train loss: 1.21e+03 - Val loss: 7.41e+03 - ES count: 11
# Epoch 55 - Train loss: 1.18e+03 - Val loss: 8.58e+03 - ES count: 12
# Epoch 56 - Train loss: 1.21e+03 - Val loss: 6.91e+03 - ES count: 13
# Epoch 57 - Train loss: 1.07e+03 - Val loss: 6.44e+03 - ES count: 0
# Epoch 58 - Train loss: 1.11e+03 - Val loss: 7.41e+03 - ES count: 1
# Epoch 59 - Train loss: 1.01e+03 - Val loss: 8.35e+03 - ES count: 2
# Epoch 60 - Train loss: 1.12e+03 - Val loss: 7.26e+03 - ES count: 3
# Epoch 61 - Train loss: 1.05e+03 - Val loss: 7.26e+03 - ES count: 4
# Epoch 62 - Train loss: 1.02e+03 - Val loss: 6.79e+03 - ES count: 5
# Epoch 63 - Train loss: 1.09e+03 - Val loss: 6.23e+03 - ES count: 0
# Epoch 64 - Train loss: 1.05e+03 - Val loss: 7.65e+03 - ES count: 1
# Epoch 65 - Train loss: 1.01e+03 - Val loss: 7.37e+03 - ES count: 2
# Epoch 66 - Train loss: 9.94e+02 - Val loss: 7.68e+03 - ES count: 3
# Epoch 67 - Train loss: 1.01e+03 - Val loss: 7.32e+03 - ES count: 4
# Epoch 68 - Train loss: 1.17e+03 - Val loss: 7.51e+03 - ES count: 5
# Epoch 69 - Train loss: 1e+03 - Val loss: 7.11e+03 - ES count: 6
# Epoch 70 - Train loss: 1.03e+03 - Val loss: 6.86e+03 - ES count: 7
# Epoch 71 - Train loss: 9.15e+02 - Val loss: 7.25e+03 - ES count: 8
# Epoch 72 - Train loss: 9.2e+02 - Val loss: 7.02e+03 - ES count: 9
# Epoch 73 - Train loss: 9.8e+02 - Val loss: 6.25e+03 - ES count: 10
# Epoch 74 - Train loss: 9.56e+02 - Val loss: 6.83e+03 - ES count: 11
# Epoch 75 - Train loss: 9.52e+02 - Val loss: 6.07e+03 - ES count: 0
# Epoch 76 - Train loss: 8.53e+02 - Val loss: 5.74e+03 - ES count: 0
# Epoch 77 - Train loss: 8.68e+02 - Val loss: 5.43e+03 - ES count: 0
# Epoch 78 - Train loss: 8.46e+02 - Val loss: 5.8e+03 - ES count: 1
# Epoch 79 - Train loss: 8.96e+02 - Val loss: 6.54e+03 - ES count: 2
# Epoch 80 - Train loss: 8.8e+02 - Val loss: 6.62e+03 - ES count: 3
# Epoch 81 - Train loss: 8.04e+02 - Val loss: 6.27e+03 - ES count: 4
# Epoch 82 - Train loss: 9.48e+02 - Val loss: 6.21e+03 - ES count: 5
# Epoch 83 - Train loss: 8.3e+02 - Val loss: 6.36e+03 - ES count: 6
# Epoch 84 - Train loss: 8.85e+02 - Val loss: 5.63e+03 - ES count: 7
# Epoch 85 - Train loss: 8.44e+02 - Val loss: 5.33e+03 - ES count: 0
# Epoch 86 - Train loss: 8.9e+02 - Val loss: 5.81e+03 - ES count: 1
# Epoch 87 - Train loss: 9.03e+02 - Val loss: 5.75e+03 - ES count: 2
# Epoch 88 - Train loss: 8.46e+02 - Val loss: 4.89e+03 - ES count: 0
# Epoch 89 - Train loss: 8.3e+02 - Val loss: 6e+03 - ES count: 1
# Epoch 90 - Train loss: 9.01e+02 - Val loss: 7.06e+03 - ES count: 2
# Epoch 91 - Train loss: 8.87e+02 - Val loss: 5.61e+03 - ES count: 3
# Epoch 92 - Train loss: 8.22e+02 - Val loss: 6.11e+03 - ES count: 4
# Epoch 93 - Train loss: 8.54e+02 - Val loss: 6.11e+03 - ES count: 5
# Epoch 94 - Train loss: 8.36e+02 - Val loss: 5.83e+03 - ES count: 6
# Epoch 95 - Train loss: 8.69e+02 - Val loss: 6.91e+03 - ES count: 7
# Epoch 96 - Train loss: 7.91e+02 - Val loss: 5.68e+03 - ES count: 8
# Epoch 97 - Train loss: 8.06e+02 - Val loss: 5.97e+03 - ES count: 9
# Epoch 98 - Train loss: 8.42e+02 - Val loss: 6.14e+03 - ES count: 10
# Epoch 99 - Train loss: 7.76e+02 - Val loss: 6.06e+03 - ES count: 11
# Epoch 100 - Train loss: 8.46e+02 - Val loss: 5.81e+03 - ES count: 12
# Epoch 101 - Train loss: 8.14e+02 - Val loss: 5.88e+03 - ES count: 13
# Epoch 102 - Train loss: 8.01e+02 - Val loss: 6.58e+03 - ES count: 14
# Epoch 103 - Train loss: 7.57e+02 - Val loss: 5.75e+03 - ES count: 15
# Epoch 104 - Train loss: 8.23e+02 - Val loss: 6.51e+03 - ES count: 16
# Epoch 105 - Train loss: 7.68e+02 - Val loss: 5.76e+03 - ES count: 17
# Epoch 106 - Train loss: 7.99e+02 - Val loss: 5.63e+03 - ES count: 18
# Epoch 107 - Train loss: 7.66e+02 - Val loss: 5.16e+03 - ES count: 19
# Epoch 108 - Train loss: 7.86e+02 - Val loss: 5.35e+03 - ES count: 20
# Epoch 109 - Train loss: 8.2e+02 - Val loss: 5.62e+03 - ES count: 21
# Epoch 110 - Train loss: 7.57e+02 - Val loss: 6.25e+03 - ES count: 22
# Epoch 111 - Train loss: 8.24e+02 - Val loss: 5.74e+03 - ES count: 23
# Epoch 112 - Train loss: 7.8e+02 - Val loss: 5.97e+03 - ES count: 24
# Epoch 113 - Train loss: 7.89e+02 - Val loss: 6.22e+03 - ES count: 25
# Epoch 114 - Train loss: 7.22e+02 - Val loss: 5.63e+03 - ES count: 26
# Epoch 115 - Train loss: 7.56e+02 - Val loss: 5.44e+03 - ES count: 27
# Epoch 116 - Train loss: 7.76e+02 - Val loss: 5.46e+03 - ES count: 28
# Epoch 117 - Train loss: 7.42e+02 - Val loss: 6.46e+03 - ES count: 29
# Epoch 118 - Train loss: 7.91e+02 - Val loss: 5.7e+03 - ES count: 30

# %%
prop_pnn_model = PropPNN(M=M, D=D, hidden_units = [16, 8], conv_channels = [16, 1], embedding_dim = 10, dropout_probs = [0.15, 0.1], device="cpu")
prop_pnn_model.load_state_dict(torch.load(project_dir /"src" / "outputs" / "weights" / f"weights-PropPNN"))

prop_pnn_train_samples, train_z_true = eval_prop_pnn(train_prop_pnn_dataset, prop_pnn_model)
plot_prop_pnn_preds(prop_pnn_train_samples,train_prop_pnn_dataset)
train_y_true = train_z_true.sum(-1)
print(f"CRPS: {crps_ensemble(train_y_true.squeeze(-1), prop_pnn_train_samples).mean()}")

prop_pnn_val_samples, val_z_true = eval_prop_pnn(val_prop_pnn_dataset, prop_pnn_model)
plot_prop_pnn_preds(prop_pnn_val_samples,val_prop_pnn_dataset)
val_y_true = val_z_true.sum(-1)
print(f"CRPS: {crps_ensemble(val_y_true.squeeze(-1), prop_pnn_val_samples).mean()}")

prop_pnn_test_samples, test_z_true = eval_prop_pnn(test_prop_pnn_dataset, prop_pnn_model)
plot_prop_pnn_preds(prop_pnn_test_samples,test_prop_pnn_dataset, project_dir/"src"/"outputs"/"visuals"/"same-day-nowcasts/PropPNN.png")
test_y_true = test_z_true.sum(-1)
print(f"CRPS: {crps_ensemble(test_y_true.squeeze(-1), prop_pnn_test_samples).mean()}")
print(f"PICA: {compute_pica(np.array(test_y_true), prop_pnn_test_samples)}")
# Out:
# CRPS: 306.923536803653
# CRPS: 641.2920076712328
# CRPS: 415.9242754098361
# PICA: 0.20136612021857914
