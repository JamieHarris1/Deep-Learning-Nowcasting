# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import random
import datetime
from torch.utils.data import DataLoader, Dataset
import torch
sys.path.append(os.path.abspath('../src'))

from data_tools.data_utils import create_data_split
from PNN.train_utils import train, EarlyStopper
from PNN.NowcastPNN import PropNet, NowcastPNNDOW

# Set seeds for batch shuffle and during training

def set_seed(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed = 123
set_seed(seed)
project_dir = project_dir = Path.cwd().parent
D = 40
M = 50


create_data_split(
    start_year=2013,
    end_year=2020,
    D=D,
    data_folder_path = project_dir / "data",
    input_filename="DENGSP.csv",
    train_prop=0.4,
    val_prop=0.3,
    test_prop=0.3
)


complete_df = pd.read_csv(project_dir / "data" / "model" / "complete_data.csv",
    parse_dates=True,
    date_format="%Y %b",
    index_col=0,
    dtype={"value": float},
)

train_df = pd.read_csv(project_dir / "data" / "model" / "training_data.csv",
    parse_dates=True,
    date_format="%Y %b",
    index_col=0,
    dtype={"value": float},
)

val_df = pd.read_csv(project_dir / "data" / "model" / "validation_data.csv",
    parse_dates=True,
    date_format="%Y %b",
    index_col=0,
    dtype={"value": float},
)
test_df = pd.read_csv(project_dir / "data" / "model" / "test_data.csv",
    parse_dates=True,
    date_format="%Y %b",
    index_col=0,
    dtype={"value": float},
)
# Out:
# /Users/jamieharris/Documents/GitHub/Imperial/Dengue-Nowcasting-Thesis/src/data_tools/data_utils.py:19: DtypeWarning: Columns (7,11,23,45,46,47,55,65,69,75,86,102) have mixed types. Specify dtype option on import or set low_memory=False.
#   dengdf_raw = pd.read_csv(input_data_path, index_col=0)

# %%
class ReportingDataset(Dataset):
    # first available datapoint is index self.D - 1,
    # e.g D=40, then self.df[39] is first day with a reporting triangle of length 40 

    def __init__(self, df, D, M, max_val, label_type, device):
        self.M = M
        self.D = D
        self.dates = pd.to_datetime(df.copy().index[self.M-1:])
        self.df = np.array(df.copy(), dtype = np.float32)
        self.max_val = max_val
        self.label_type = label_type
        self.device = device

        assert self.label_type in ("y", "z"), 'label_type must either be "y" or "z"'

    def __len__(self):
        return len(self.df) - self.M + 1


    def __getitem__(self, idx):
        t = idx + self.M
        obs = self.df[t-self.M: t]

        # Create observed reporting triangle
        mask = self.get_mask()
        obs_masked = obs.copy() / self.max_val
        obs_masked[-self.D:, :][~mask] = 0
        obs_masked = torch.tensor(obs_masked, dtype=torch.float32)
        obs_masked = obs_masked.to(self.device)

        # Get day of the week and week num
        date = self.get_date(idx)
        dow = torch.tensor(date.weekday(), dtype=torch.int32)
        dow.to(self.device)
        # week = torch.tensor(date.isocalendar().week - 1, dtype=torch.int32)
        # week.to(self.device)


        
        if self.label_type == 'y':
            # Create y label
            y_label = torch.tensor(obs[self.M - 1, :].sum(), dtype=torch.float32)
            y_label.to(self.device)
            return (obs_masked, dow), y_label
        
        elif self.label_type == 'z':
            # Create z label
            z_label = torch.tensor(obs[self.M - 1, :], dtype=torch.float32)
            z_label.to(self.device)
            return (obs_masked, dow), z_label
            
    
    def get_mask(self):
        mask_matrix = np.ones(shape=(self.D, self.D), dtype=bool)
        for i in range(self.D):
            for j in range(self.D):
                if i + j > self.D - 1:
                    mask_matrix[i, j] = False
        return mask_matrix

    def get_date(self, idx):
        return self.dates[idx].date()
    
    def get_y(self, idx):
        t = idx + self.M
        return np.array(self.df[t-1].sum())

max_val = train_df.values.max()

# %%
def eval_model(dataset, model, label_type):
    eval_loader = DataLoader(dataset, batch_size=dataset.__len__(), shuffle=False)

    # Put model in eval mode with dropout active
    model.eval()
    model.drop_count1.train()
    model.drop_count2.train()
    # model.drop_prop1.train()

    (matrix, dow), label = next(iter(eval_loader))
    matrix = matrix.to("cpu")
    dow = dow.to("cpu")
    model = model.to("cpu")

    n_samples = 500
    preds = np.zeros(shape=(dataset.__len__(), n_samples))
    for i in range(n_samples):
        dist = model(matrix, dow)
        samples = dist.sample().numpy()
        if label_type == 'z':
            samples = samples.sum(axis=-1)
        preds[:, i] = samples

    return preds

def plot_preds(preds, dataset, title, other_preds=False, other_preds_label=False):
    preds_median = np.quantile(preds, 0.5, axis=1)
    y_true = [dataset.get_y(idx) for idx in range(dataset.__len__())]
    dates = pd.to_datetime(dataset.dates)
    plt.plot(dates, preds_median, label='preds')
    if other_preds is not False:
        plt.plot(dates, other_preds, label=other_preds_label)
    plt.plot(dates, y_true, label='y')
    plt.legend()
    plt.title(title)
    plt.xticks(rotation=45)
    plt.show()

# %%
device = "cpu"

complete_dataset = ReportingDataset(complete_df, D, M, max_val, label_type='z', device=device)
train_dataset = ReportingDataset(train_df, D, M, max_val, label_type='z', device=device)
val_dataset = ReportingDataset(val_df, D, M, max_val, label_type='z', device=device)
test_dataset = ReportingDataset(test_df, D, M, max_val, label_type='z', device=device)

# Create dataloaders, shuffle trainign data for better training
g = torch.Generator()
g.manual_seed(seed)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, generator=g)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)



early_stopper = EarlyStopper(patience=30, past_units=M, max_delay=D, weeks=False, future_obs=0, random_split=False, dow = True)
prop_net = PropNet(max_val=max_val, D=D, M=M)

# %%
train(prop_net, num_epochs=400, train_loader=train_loader, val_loader=val_loader, early_stopper=early_stopper, loss_fct="nll", device = device, dow = True, label_type='z')
# Out:
# Epoch 1 - Train loss: 3.69e+03 - Val loss: 4.61e+04 - ES count: 0
# Epoch 2 - Train loss: 3.22e+03 - Val loss: 3.48e+04 - ES count: 0
# Epoch 3 - Train loss: 3.07e+03 - Val loss: 2.96e+04 - ES count: 0
# Epoch 4 - Train loss: 2.92e+03 - Val loss: 2.63e+04 - ES count: 0
# Epoch 5 - Train loss: 2.82e+03 - Val loss: 2.7e+04 - ES count: 1
# Epoch 6 - Train loss: 2.72e+03 - Val loss: 2.25e+04 - ES count: 0
# Epoch 7 - Train loss: 2.56e+03 - Val loss: 2.38e+04 - ES count: 1
# Epoch 8 - Train loss: 2.38e+03 - Val loss: 2.31e+04 - ES count: 2
# Epoch 9 - Train loss: 2.18e+03 - Val loss: 2.13e+04 - ES count: 0
# Epoch 10 - Train loss: 2e+03 - Val loss: 2.08e+04 - ES count: 0
# Epoch 11 - Train loss: 1.86e+03 - Val loss: 1.9e+04 - ES count: 0
# Epoch 12 - Train loss: 1.86e+03 - Val loss: 1.8e+04 - ES count: 0
# Epoch 13 - Train loss: 1.71e+03 - Val loss: 1.84e+04 - ES count: 1
# Epoch 14 - Train loss: 1.66e+03 - Val loss: 1.71e+04 - ES count: 0
# Epoch 15 - Train loss: 1.56e+03 - Val loss: 1.81e+04 - ES count: 1
# Epoch 16 - Train loss: 1.54e+03 - Val loss: 1.57e+04 - ES count: 0
# Epoch 17 - Train loss: 1.48e+03 - Val loss: 1.5e+04 - ES count: 0
# Epoch 18 - Train loss: 1.4e+03 - Val loss: 1.4e+04 - ES count: 0
# Epoch 19 - Train loss: 1.38e+03 - Val loss: 1.56e+04 - ES count: 1
# Epoch 20 - Train loss: 1.3e+03 - Val loss: 1.33e+04 - ES count: 0
# Epoch 21 - Train loss: 1.26e+03 - Val loss: 1.4e+04 - ES count: 1
# Epoch 22 - Train loss: 1.26e+03 - Val loss: 1.19e+04 - ES count: 0
# Epoch 23 - Train loss: 1.17e+03 - Val loss: 1.35e+04 - ES count: 1
# Epoch 24 - Train loss: 1.13e+03 - Val loss: 1.21e+04 - ES count: 2
# Epoch 25 - Train loss: 1.09e+03 - Val loss: 1.17e+04 - ES count: 0
# Epoch 26 - Train loss: 1.06e+03 - Val loss: 1.27e+04 - ES count: 1
# Epoch 27 - Train loss: 9.95e+02 - Val loss: 1.16e+04 - ES count: 0
# Epoch 28 - Train loss: 9.95e+02 - Val loss: 9.62e+03 - ES count: 0
# Epoch 29 - Train loss: 9.83e+02 - Val loss: 1.1e+04 - ES count: 1
# Epoch 30 - Train loss: 9.49e+02 - Val loss: 9.99e+03 - ES count: 2
# Epoch 31 - Train loss: 9.49e+02 - Val loss: 8.99e+03 - ES count: 0
# Epoch 32 - Train loss: 9.19e+02 - Val loss: 9.05e+03 - ES count: 1
# Epoch 33 - Train loss: 8.87e+02 - Val loss: 8.99e+03 - ES count: 2
# Epoch 34 - Train loss: 8.7e+02 - Val loss: 8.68e+03 - ES count: 0
# Epoch 35 - Train loss: 8.82e+02 - Val loss: 8.43e+03 - ES count: 0
# Epoch 36 - Train loss: 8.12e+02 - Val loss: 8.44e+03 - ES count: 1
# Epoch 37 - Train loss: 8.11e+02 - Val loss: 7.67e+03 - ES count: 0
# Epoch 38 - Train loss: 8.62e+02 - Val loss: 7.73e+03 - ES count: 1
# Epoch 39 - Train loss: 8.19e+02 - Val loss: 6.92e+03 - ES count: 0
# Epoch 40 - Train loss: 7.84e+02 - Val loss: 7.08e+03 - ES count: 1
# Epoch 41 - Train loss: 7.81e+02 - Val loss: 7.12e+03 - ES count: 2
# Epoch 42 - Train loss: 7.61e+02 - Val loss: 7.12e+03 - ES count: 3
# Epoch 43 - Train loss: 7.59e+02 - Val loss: 6.81e+03 - ES count: 0
# Epoch 44 - Train loss: 7.39e+02 - Val loss: 7.29e+03 - ES count: 1
# Epoch 45 - Train loss: 7.22e+02 - Val loss: 6.38e+03 - ES count: 0
# Epoch 46 - Train loss: 7.36e+02 - Val loss: 6.67e+03 - ES count: 1
# Epoch 47 - Train loss: 7.35e+02 - Val loss: 6.51e+03 - ES count: 2
# Epoch 48 - Train loss: 7.21e+02 - Val loss: 6.5e+03 - ES count: 3
# Epoch 49 - Train loss: 6.73e+02 - Val loss: 6.61e+03 - ES count: 4
# Epoch 50 - Train loss: 6.77e+02 - Val loss: 6.36e+03 - ES count: 0
# Epoch 51 - Train loss: 6.75e+02 - Val loss: 6.96e+03 - ES count: 1
# Epoch 52 - Train loss: 6.71e+02 - Val loss: 6.1e+03 - ES count: 0
# Epoch 53 - Train loss: 6.37e+02 - Val loss: 6.21e+03 - ES count: 1
# Epoch 54 - Train loss: 6.76e+02 - Val loss: 5.73e+03 - ES count: 0
# Epoch 55 - Train loss: 6.52e+02 - Val loss: 5.63e+03 - ES count: 0
# Epoch 56 - Train loss: 6.1e+02 - Val loss: 6.27e+03 - ES count: 1
# Epoch 57 - Train loss: 6.19e+02 - Val loss: 5.89e+03 - ES count: 2
# Epoch 58 - Train loss: 6.29e+02 - Val loss: 5.69e+03 - ES count: 3
# Epoch 59 - Train loss: 6.01e+02 - Val loss: 5.89e+03 - ES count: 4
# Epoch 60 - Train loss: 5.82e+02 - Val loss: 5.86e+03 - ES count: 5
# Epoch 61 - Train loss: 5.82e+02 - Val loss: 5.51e+03 - ES count: 0
# Epoch 62 - Train loss: 5.95e+02 - Val loss: 5.56e+03 - ES count: 1
# Epoch 63 - Train loss: 5.93e+02 - Val loss: 5.59e+03 - ES count: 2
# Epoch 64 - Train loss: 5.74e+02 - Val loss: 5.29e+03 - ES count: 0
# Epoch 65 - Train loss: 5.61e+02 - Val loss: 5.68e+03 - ES count: 1
# Epoch 66 - Train loss: 6.13e+02 - Val loss: 5.06e+03 - ES count: 0
# Epoch 67 - Train loss: 5.49e+02 - Val loss: 5.23e+03 - ES count: 1
# Epoch 68 - Train loss: 5.5e+02 - Val loss: 5.27e+03 - ES count: 2
# Epoch 69 - Train loss: 5.51e+02 - Val loss: 5.37e+03 - ES count: 3
# Epoch 70 - Train loss: 5.42e+02 - Val loss: 4.98e+03 - ES count: 0
# Epoch 71 - Train loss: 5.16e+02 - Val loss: 5.44e+03 - ES count: 1
# Epoch 72 - Train loss: 5.33e+02 - Val loss: 4.96e+03 - ES count: 0
# Epoch 73 - Train loss: 5.17e+02 - Val loss: 4.95e+03 - ES count: 0
# Epoch 74 - Train loss: 5.12e+02 - Val loss: 5.2e+03 - ES count: 1
# Epoch 75 - Train loss: 5.73e+02 - Val loss: 4.86e+03 - ES count: 0
# Epoch 76 - Train loss: 5.19e+02 - Val loss: 4.63e+03 - ES count: 0
# Epoch 77 - Train loss: 5.19e+02 - Val loss: 4.66e+03 - ES count: 1
# Epoch 78 - Train loss: 5.23e+02 - Val loss: 5.13e+03 - ES count: 2
# Epoch 79 - Train loss: 5.1e+02 - Val loss: 4.54e+03 - ES count: 0
# Epoch 80 - Train loss: 5.07e+02 - Val loss: 4.65e+03 - ES count: 1
# Epoch 81 - Train loss: 5e+02 - Val loss: 4.77e+03 - ES count: 2
# Epoch 82 - Train loss: 4.82e+02 - Val loss: 4.89e+03 - ES count: 3
# Epoch 83 - Train loss: 4.74e+02 - Val loss: 4.62e+03 - ES count: 4
# Epoch 84 - Train loss: 4.92e+02 - Val loss: 4.88e+03 - ES count: 5
# Epoch 85 - Train loss: 4.71e+02 - Val loss: 4.3e+03 - ES count: 0
# Epoch 86 - Train loss: 5.14e+02 - Val loss: 4.65e+03 - ES count: 1
# Epoch 87 - Train loss: 4.89e+02 - Val loss: 4.11e+03 - ES count: 0
# Epoch 88 - Train loss: 4.69e+02 - Val loss: 4.07e+03 - ES count: 0
# Epoch 89 - Train loss: 4.49e+02 - Val loss: 4.41e+03 - ES count: 1
# Epoch 90 - Train loss: 4.78e+02 - Val loss: 4.33e+03 - ES count: 2
# Epoch 91 - Train loss: 4.7e+02 - Val loss: 4.78e+03 - ES count: 3
# Epoch 92 - Train loss: 4.6e+02 - Val loss: 4.18e+03 - ES count: 4
# Epoch 93 - Train loss: 4.65e+02 - Val loss: 4.73e+03 - ES count: 5
# Epoch 94 - Train loss: 4.62e+02 - Val loss: 4.5e+03 - ES count: 6
# Epoch 95 - Train loss: 4.56e+02 - Val loss: 4.42e+03 - ES count: 7
# Epoch 96 - Train loss: 4.57e+02 - Val loss: 4.59e+03 - ES count: 8
# Epoch 97 - Train loss: 4.44e+02 - Val loss: 4.33e+03 - ES count: 9
# Epoch 98 - Train loss: 4.5e+02 - Val loss: 4.35e+03 - ES count: 10
# Epoch 99 - Train loss: 4.5e+02 - Val loss: 4.07e+03 - ES count: 11
# Epoch 100 - Train loss: 4.49e+02 - Val loss: 4.04e+03 - ES count: 0
# Epoch 101 - Train loss: 4.36e+02 - Val loss: 4.13e+03 - ES count: 1
# Epoch 102 - Train loss: 4.81e+02 - Val loss: 4.12e+03 - ES count: 2
# Epoch 103 - Train loss: 4.43e+02 - Val loss: 3.99e+03 - ES count: 0
# Epoch 104 - Train loss: 4.43e+02 - Val loss: 4.19e+03 - ES count: 1
# Epoch 105 - Train loss: 4.61e+02 - Val loss: 4.43e+03 - ES count: 2
# Epoch 106 - Train loss: 4.42e+02 - Val loss: 4.47e+03 - ES count: 3
# Epoch 107 - Train loss: 4.54e+02 - Val loss: 3.9e+03 - ES count: 0
# Epoch 108 - Train loss: 4.35e+02 - Val loss: 4.5e+03 - ES count: 1
# Epoch 109 - Train loss: 4.28e+02 - Val loss: 3.99e+03 - ES count: 2
# Epoch 110 - Train loss: 4.25e+02 - Val loss: 4.03e+03 - ES count: 3
# Epoch 111 - Train loss: 4.29e+02 - Val loss: 4.12e+03 - ES count: 4
# Epoch 112 - Train loss: 4.44e+02 - Val loss: 4.05e+03 - ES count: 5
# Epoch 113 - Train loss: 4.32e+02 - Val loss: 4.04e+03 - ES count: 6
# Epoch 114 - Train loss: 4.21e+02 - Val loss: 3.74e+03 - ES count: 0
# Epoch 115 - Train loss: 4.12e+02 - Val loss: 4.23e+03 - ES count: 1
# Epoch 116 - Train loss: 4.31e+02 - Val loss: 4.09e+03 - ES count: 2
# Epoch 117 - Train loss: 4.14e+02 - Val loss: 3.99e+03 - ES count: 3
# Epoch 118 - Train loss: 4.32e+02 - Val loss: 4.16e+03 - ES count: 4
# Epoch 119 - Train loss: 4.06e+02 - Val loss: 4.2e+03 - ES count: 5
# Epoch 120 - Train loss: 4.18e+02 - Val loss: 4.06e+03 - ES count: 6
# Epoch 121 - Train loss: 4.14e+02 - Val loss: 3.97e+03 - ES count: 7
# Epoch 122 - Train loss: 4.37e+02 - Val loss: 4.1e+03 - ES count: 8
# Epoch 123 - Train loss: 4.13e+02 - Val loss: 4.29e+03 - ES count: 9
# Epoch 124 - Train loss: 4.01e+02 - Val loss: 3.8e+03 - ES count: 10
# Epoch 125 - Train loss: 4.18e+02 - Val loss: 4.25e+03 - ES count: 11
# Epoch 126 - Train loss: 4.2e+02 - Val loss: 4.24e+03 - ES count: 12
# Epoch 127 - Train loss: 4.17e+02 - Val loss: 4e+03 - ES count: 13
# Epoch 128 - Train loss: 4.16e+02 - Val loss: 4.52e+03 - ES count: 14
# Epoch 129 - Train loss: 4.12e+02 - Val loss: 3.6e+03 - ES count: 0
# Epoch 130 - Train loss: 4.15e+02 - Val loss: 3.72e+03 - ES count: 1
# Epoch 131 - Train loss: 3.86e+02 - Val loss: 4.13e+03 - ES count: 2
# Epoch 132 - Train loss: 3.9e+02 - Val loss: 4.08e+03 - ES count: 3
# Epoch 133 - Train loss: 4.14e+02 - Val loss: 3.58e+03 - ES count: 0
# Epoch 134 - Train loss: 3.81e+02 - Val loss: 3.69e+03 - ES count: 1
# Epoch 135 - Train loss: 3.97e+02 - Val loss: 4.78e+03 - ES count: 2
# Epoch 136 - Train loss: 3.97e+02 - Val loss: 4.16e+03 - ES count: 3
# Epoch 137 - Train loss: 3.86e+02 - Val loss: 3.55e+03 - ES count: 0
# Epoch 138 - Train loss: 3.87e+02 - Val loss: 3.92e+03 - ES count: 1
# Epoch 139 - Train loss: 3.89e+02 - Val loss: 3.82e+03 - ES count: 2
# Epoch 140 - Train loss: 3.98e+02 - Val loss: 3.71e+03 - ES count: 3
# Epoch 141 - Train loss: 3.85e+02 - Val loss: 3.44e+03 - ES count: 0
# Epoch 142 - Train loss: 4.03e+02 - Val loss: 4.18e+03 - ES count: 1
# Epoch 143 - Train loss: 3.85e+02 - Val loss: 3.69e+03 - ES count: 2
# Epoch 144 - Train loss: 3.7e+02 - Val loss: 4.4e+03 - ES count: 3
# Epoch 145 - Train loss: 3.78e+02 - Val loss: 3.77e+03 - ES count: 4
# Epoch 146 - Train loss: 3.62e+02 - Val loss: 4.14e+03 - ES count: 5
# Epoch 147 - Train loss: 3.91e+02 - Val loss: 3.71e+03 - ES count: 6
# Epoch 148 - Train loss: 3.83e+02 - Val loss: 3.93e+03 - ES count: 7
# Epoch 149 - Train loss: 4.18e+02 - Val loss: 3.58e+03 - ES count: 8
# Epoch 150 - Train loss: 3.78e+02 - Val loss: 3.79e+03 - ES count: 9
# Epoch 151 - Train loss: 3.69e+02 - Val loss: 3.8e+03 - ES count: 10
# Epoch 152 - Train loss: 3.68e+02 - Val loss: 3.37e+03 - ES count: 0
# Epoch 153 - Train loss: 3.69e+02 - Val loss: 4.49e+03 - ES count: 1
# Epoch 154 - Train loss: 3.74e+02 - Val loss: 3.22e+03 - ES count: 0
# Epoch 155 - Train loss: 3.65e+02 - Val loss: 3.51e+03 - ES count: 1
# Epoch 156 - Train loss: 3.64e+02 - Val loss: 3.88e+03 - ES count: 2
# Epoch 157 - Train loss: 3.57e+02 - Val loss: 4.25e+03 - ES count: 3
# Epoch 158 - Train loss: 3.86e+02 - Val loss: 3.72e+03 - ES count: 4
# Epoch 159 - Train loss: 3.53e+02 - Val loss: 3.65e+03 - ES count: 5
# Epoch 160 - Train loss: 3.61e+02 - Val loss: 3.62e+03 - ES count: 6
# Epoch 161 - Train loss: 3.54e+02 - Val loss: 3.85e+03 - ES count: 7
# Epoch 162 - Train loss: 3.88e+02 - Val loss: 3.55e+03 - ES count: 8
# Epoch 163 - Train loss: 3.54e+02 - Val loss: 3.86e+03 - ES count: 9
# Epoch 164 - Train loss: 3.56e+02 - Val loss: 3.3e+03 - ES count: 10
# Epoch 165 - Train loss: 3.87e+02 - Val loss: 4.13e+03 - ES count: 11
# Epoch 166 - Train loss: 3.63e+02 - Val loss: 3e+03 - ES count: 0
# Epoch 167 - Train loss: 3.64e+02 - Val loss: 3.07e+03 - ES count: 1
# Epoch 168 - Train loss: 3.53e+02 - Val loss: 3.74e+03 - ES count: 2
# Epoch 169 - Train loss: 3.84e+02 - Val loss: 3.2e+03 - ES count: 3
# Epoch 170 - Train loss: 3.49e+02 - Val loss: 3.84e+03 - ES count: 4
# Epoch 171 - Train loss: 3.85e+02 - Val loss: 3.54e+03 - ES count: 5
# Epoch 172 - Train loss: 3.51e+02 - Val loss: 3.17e+03 - ES count: 6
# Epoch 173 - Train loss: 3.51e+02 - Val loss: 3.67e+03 - ES count: 7
# Epoch 174 - Train loss: 3.48e+02 - Val loss: 3.83e+03 - ES count: 8
# Epoch 175 - Train loss: 3.38e+02 - Val loss: 3.59e+03 - ES count: 9
# Epoch 176 - Train loss: 3.53e+02 - Val loss: 3.57e+03 - ES count: 10
# Epoch 177 - Train loss: 3.39e+02 - Val loss: 3.68e+03 - ES count: 11
# Epoch 178 - Train loss: 3.47e+02 - Val loss: 3.56e+03 - ES count: 12
# Epoch 179 - Train loss: 3.46e+02 - Val loss: 3.19e+03 - ES count: 13
# Epoch 180 - Train loss: 3.45e+02 - Val loss: 3.77e+03 - ES count: 14
# Epoch 181 - Train loss: 3.54e+02 - Val loss: 3.03e+03 - ES count: 15
# Epoch 182 - Train loss: 3.37e+02 - Val loss: 3.94e+03 - ES count: 16
# Epoch 183 - Train loss: 3.3e+02 - Val loss: 3.83e+03 - ES count: 17
# Epoch 184 - Train loss: 3.37e+02 - Val loss: 3.1e+03 - ES count: 18
# Epoch 185 - Train loss: 3.37e+02 - Val loss: 3.24e+03 - ES count: 19
# Epoch 186 - Train loss: 3.45e+02 - Val loss: 2.77e+03 - ES count: 0
# Epoch 187 - Train loss: 3.52e+02 - Val loss: 3.02e+03 - ES count: 1
# Epoch 188 - Train loss: 3.4e+02 - Val loss: 3.05e+03 - ES count: 2
# Epoch 189 - Train loss: 3.26e+02 - Val loss: 3.63e+03 - ES count: 3
# Epoch 190 - Train loss: 3.3e+02 - Val loss: 3.41e+03 - ES count: 4
# Epoch 191 - Train loss: 3.33e+02 - Val loss: 2.95e+03 - ES count: 5
# Epoch 192 - Train loss: 3.53e+02 - Val loss: 2.85e+03 - ES count: 6
# Epoch 193 - Train loss: 3.4e+02 - Val loss: 3.62e+03 - ES count: 7
# Epoch 194 - Train loss: 3.24e+02 - Val loss: 3.06e+03 - ES count: 8
# Epoch 195 - Train loss: 3.28e+02 - Val loss: 2.89e+03 - ES count: 9
# Epoch 196 - Train loss: 3.38e+02 - Val loss: 3.42e+03 - ES count: 10
# Epoch 197 - Train loss: 3.27e+02 - Val loss: 3.29e+03 - ES count: 11
# Epoch 198 - Train loss: 3.28e+02 - Val loss: 3.28e+03 - ES count: 12
# Epoch 199 - Train loss: 3.25e+02 - Val loss: 2.62e+03 - ES count: 0
# Epoch 200 - Train loss: 3.12e+02 - Val loss: 2.92e+03 - ES count: 1
# Epoch 201 - Train loss: 3.39e+02 - Val loss: 2.75e+03 - ES count: 2
# Epoch 202 - Train loss: 3.44e+02 - Val loss: 4.01e+03 - ES count: 3
# Epoch 203 - Train loss: 3.36e+02 - Val loss: 4.25e+03 - ES count: 4
# Epoch 204 - Train loss: 3.26e+02 - Val loss: 3.73e+03 - ES count: 5
# Epoch 205 - Train loss: 3.17e+02 - Val loss: 3.26e+03 - ES count: 6
# Epoch 206 - Train loss: 3.27e+02 - Val loss: 3.61e+03 - ES count: 7
# Epoch 207 - Train loss: 3.23e+02 - Val loss: 3.51e+03 - ES count: 8
# Epoch 208 - Train loss: 3.25e+02 - Val loss: 3.14e+03 - ES count: 9
# Epoch 209 - Train loss: 3.42e+02 - Val loss: 2.79e+03 - ES count: 10
# Epoch 210 - Train loss: 3.18e+02 - Val loss: 2.98e+03 - ES count: 11
# Epoch 211 - Train loss: 3.13e+02 - Val loss: 2.91e+03 - ES count: 12
# Epoch 212 - Train loss: 3.36e+02 - Val loss: 2.93e+03 - ES count: 13
# Epoch 213 - Train loss: 3.22e+02 - Val loss: 3.48e+03 - ES count: 14
# Epoch 214 - Train loss: 3.17e+02 - Val loss: 3.38e+03 - ES count: 15
# Epoch 215 - Train loss: 3.2e+02 - Val loss: 3.71e+03 - ES count: 16
# Epoch 216 - Train loss: 3.29e+02 - Val loss: 2.75e+03 - ES count: 17
# Epoch 217 - Train loss: 3.08e+02 - Val loss: 2.98e+03 - ES count: 18
# Epoch 218 - Train loss: 3.33e+02 - Val loss: 3.16e+03 - ES count: 19
# Epoch 219 - Train loss: 3.27e+02 - Val loss: 3.09e+03 - ES count: 20
# Epoch 220 - Train loss: 3.11e+02 - Val loss: 3.43e+03 - ES count: 21
# Epoch 221 - Train loss: 3.06e+02 - Val loss: 3.25e+03 - ES count: 22
# Epoch 222 - Train loss: 3.16e+02 - Val loss: 3.04e+03 - ES count: 23
# Epoch 223 - Train loss: 3.11e+02 - Val loss: 2.67e+03 - ES count: 24
# Epoch 224 - Train loss: 3.23e+02 - Val loss: 2.59e+03 - ES count: 0
# Epoch 225 - Train loss: 3.1e+02 - Val loss: 2.96e+03 - ES count: 1
# Epoch 226 - Train loss: 3.16e+02 - Val loss: 3.06e+03 - ES count: 2
# Epoch 227 - Train loss: 3.1e+02 - Val loss: 3.21e+03 - ES count: 3
# Epoch 228 - Train loss: 3.21e+02 - Val loss: 2.85e+03 - ES count: 4
# Epoch 229 - Train loss: 3.31e+02 - Val loss: 2.89e+03 - ES count: 5
# Epoch 230 - Train loss: 2.95e+02 - Val loss: 2.81e+03 - ES count: 6
# Epoch 231 - Train loss: 3.03e+02 - Val loss: 3.47e+03 - ES count: 7
# Epoch 232 - Train loss: 3.13e+02 - Val loss: 3.02e+03 - ES count: 8
# Epoch 233 - Train loss: 3.06e+02 - Val loss: 3.12e+03 - ES count: 9
# Epoch 234 - Train loss: 3.09e+02 - Val loss: 3.51e+03 - ES count: 10
# Epoch 235 - Train loss: 3.16e+02 - Val loss: 3.19e+03 - ES count: 11
# Epoch 236 - Train loss: 3.04e+02 - Val loss: 2.66e+03 - ES count: 12
# Epoch 237 - Train loss: 2.99e+02 - Val loss: 2.69e+03 - ES count: 13
# Epoch 238 - Train loss: 3.02e+02 - Val loss: 3.69e+03 - ES count: 14
# Epoch 239 - Train loss: 3.54e+02 - Val loss: 2.84e+03 - ES count: 15
# Epoch 240 - Train loss: 2.91e+02 - Val loss: 2.91e+03 - ES count: 16
# Epoch 241 - Train loss: 3.05e+02 - Val loss: 2.86e+03 - ES count: 17
# Epoch 242 - Train loss: 3.14e+02 - Val loss: 3.14e+03 - ES count: 18
# Epoch 243 - Train loss: 3.08e+02 - Val loss: 3.01e+03 - ES count: 19
# Epoch 244 - Train loss: 2.88e+02 - Val loss: 3.54e+03 - ES count: 20
# Epoch 245 - Train loss: 2.98e+02 - Val loss: 2.55e+03 - ES count: 0
# Epoch 246 - Train loss: 3.21e+02 - Val loss: 2.53e+03 - ES count: 0
# Epoch 247 - Train loss: 3.22e+02 - Val loss: 2.76e+03 - ES count: 1
# Epoch 248 - Train loss: 3.03e+02 - Val loss: 2.78e+03 - ES count: 2
# Epoch 249 - Train loss: 3.15e+02 - Val loss: 2.83e+03 - ES count: 3
# Epoch 250 - Train loss: 3.12e+02 - Val loss: 3.53e+03 - ES count: 4
# Epoch 251 - Train loss: 3.03e+02 - Val loss: 3.15e+03 - ES count: 5
# Epoch 252 - Train loss: 3.04e+02 - Val loss: 3.6e+03 - ES count: 6
# Epoch 253 - Train loss: 2.92e+02 - Val loss: 3.2e+03 - ES count: 7
# Epoch 254 - Train loss: 3.05e+02 - Val loss: 3.16e+03 - ES count: 8
# Epoch 255 - Train loss: 2.89e+02 - Val loss: 2.62e+03 - ES count: 9
# Epoch 256 - Train loss: 3.3e+02 - Val loss: 3.04e+03 - ES count: 10
# Epoch 257 - Train loss: 2.99e+02 - Val loss: 2.77e+03 - ES count: 11
# Epoch 258 - Train loss: 3.14e+02 - Val loss: 3.03e+03 - ES count: 12
# Epoch 259 - Train loss: 3.02e+02 - Val loss: 2.59e+03 - ES count: 13
# Epoch 260 - Train loss: 3.13e+02 - Val loss: 2.72e+03 - ES count: 14
# Epoch 261 - Train loss: 2.98e+02 - Val loss: 3e+03 - ES count: 15
# Epoch 262 - Train loss: 3e+02 - Val loss: 2.67e+03 - ES count: 16
# Epoch 263 - Train loss: 2.95e+02 - Val loss: 2.4e+03 - ES count: 0
# Epoch 264 - Train loss: 2.98e+02 - Val loss: 3.28e+03 - ES count: 1
# Epoch 265 - Train loss: 3.22e+02 - Val loss: 2.62e+03 - ES count: 2
# Epoch 266 - Train loss: 2.94e+02 - Val loss: 3.25e+03 - ES count: 3
# Epoch 267 - Train loss: 2.95e+02 - Val loss: 3.56e+03 - ES count: 4
# Epoch 268 - Train loss: 2.91e+02 - Val loss: 2.96e+03 - ES count: 5
# Epoch 269 - Train loss: 2.99e+02 - Val loss: 3.38e+03 - ES count: 6
# Epoch 270 - Train loss: 2.97e+02 - Val loss: 3.65e+03 - ES count: 7
# Epoch 271 - Train loss: 3.06e+02 - Val loss: 2.43e+03 - ES count: 8
# Epoch 272 - Train loss: 2.88e+02 - Val loss: 3.29e+03 - ES count: 9
# Epoch 273 - Train loss: 3.11e+02 - Val loss: 2.56e+03 - ES count: 10
# Epoch 274 - Train loss: 3.43e+02 - Val loss: 2.68e+03 - ES count: 11
# Epoch 275 - Train loss: 2.79e+02 - Val loss: 2.64e+03 - ES count: 12
# Epoch 276 - Train loss: 2.86e+02 - Val loss: 2.77e+03 - ES count: 13
# Epoch 277 - Train loss: 2.9e+02 - Val loss: 2.99e+03 - ES count: 14
# Epoch 278 - Train loss: 2.96e+02 - Val loss: 3e+03 - ES count: 15
# Epoch 279 - Train loss: 2.84e+02 - Val loss: 3.72e+03 - ES count: 16
# Epoch 280 - Train loss: 3.06e+02 - Val loss: 2.97e+03 - ES count: 17
# Epoch 281 - Train loss: 2.84e+02 - Val loss: 3.17e+03 - ES count: 18
# Epoch 282 - Train loss: 2.88e+02 - Val loss: 3.09e+03 - ES count: 19
# Epoch 283 - Train loss: 2.73e+02 - Val loss: 2.35e+03 - ES count: 0
# Epoch 284 - Train loss: 2.83e+02 - Val loss: 3.21e+03 - ES count: 1
# Epoch 285 - Train loss: 2.89e+02 - Val loss: 2.89e+03 - ES count: 2
# Epoch 286 - Train loss: 2.96e+02 - Val loss: 2.47e+03 - ES count: 3
# Epoch 287 - Train loss: 2.98e+02 - Val loss: 3.5e+03 - ES count: 4
# Epoch 288 - Train loss: 2.82e+02 - Val loss: 2.58e+03 - ES count: 5
# Epoch 289 - Train loss: 2.89e+02 - Val loss: 2.41e+03 - ES count: 6
# Epoch 290 - Train loss: 2.98e+02 - Val loss: 3.36e+03 - ES count: 7
# Epoch 291 - Train loss: 2.8e+02 - Val loss: 3.06e+03 - ES count: 8
# Epoch 292 - Train loss: 3e+02 - Val loss: 2.72e+03 - ES count: 9
# Epoch 293 - Train loss: 2.86e+02 - Val loss: 3.26e+03 - ES count: 10
# Epoch 294 - Train loss: 2.88e+02 - Val loss: 2.81e+03 - ES count: 11
# Epoch 295 - Train loss: 2.85e+02 - Val loss: 3.26e+03 - ES count: 12
# Epoch 296 - Train loss: 2.97e+02 - Val loss: 2.76e+03 - ES count: 13
# Epoch 297 - Train loss: 2.89e+02 - Val loss: 3.18e+03 - ES count: 14
# Epoch 298 - Train loss: 3.05e+02 - Val loss: 2.54e+03 - ES count: 15
# Epoch 299 - Train loss: 2.9e+02 - Val loss: 2.95e+03 - ES count: 16
# Epoch 300 - Train loss: 2.87e+02 - Val loss: 2.46e+03 - ES count: 17
# Epoch 301 - Train loss: 2.68e+02 - Val loss: 2.42e+03 - ES count: 18
# Epoch 302 - Train loss: 2.84e+02 - Val loss: 3.02e+03 - ES count: 19
# Epoch 303 - Train loss: 2.79e+02 - Val loss: 2.54e+03 - ES count: 20
# Epoch 304 - Train loss: 2.81e+02 - Val loss: 3.04e+03 - ES count: 21
# Epoch 305 - Train loss: 2.74e+02 - Val loss: 2.51e+03 - ES count: 22
# Epoch 306 - Train loss: 3e+02 - Val loss: 2.4e+03 - ES count: 23
# Epoch 307 - Train loss: 2.86e+02 - Val loss: 2.69e+03 - ES count: 24
# Epoch 308 - Train loss: 2.78e+02 - Val loss: 2.77e+03 - ES count: 25
# Epoch 309 - Train loss: 2.84e+02 - Val loss: 2.91e+03 - ES count: 26
# Epoch 310 - Train loss: 2.91e+02 - Val loss: 2.6e+03 - ES count: 27
# Epoch 311 - Train loss: 2.92e+02 - Val loss: 3.57e+03 - ES count: 28
# Epoch 312 - Train loss: 2.91e+02 - Val loss: 2.64e+03 - ES count: 29
# Epoch 313 - Train loss: 2.75e+02 - Val loss: 2.32e+03 - ES count: 0
# Epoch 314 - Train loss: 2.67e+02 - Val loss: 2.55e+03 - ES count: 1
# Epoch 315 - Train loss: 2.88e+02 - Val loss: 3.35e+03 - ES count: 2
# Epoch 316 - Train loss: 2.83e+02 - Val loss: 2.48e+03 - ES count: 3
# Epoch 317 - Train loss: 2.85e+02 - Val loss: 2.98e+03 - ES count: 4
# Epoch 318 - Train loss: 2.99e+02 - Val loss: 2.41e+03 - ES count: 5
# Epoch 319 - Train loss: 2.85e+02 - Val loss: 2.55e+03 - ES count: 6
# Epoch 320 - Train loss: 2.76e+02 - Val loss: 2.9e+03 - ES count: 7
# Epoch 321 - Train loss: 2.71e+02 - Val loss: 2.56e+03 - ES count: 8
# Epoch 322 - Train loss: 2.93e+02 - Val loss: 2.83e+03 - ES count: 9
# Epoch 323 - Train loss: 2.74e+02 - Val loss: 2.69e+03 - ES count: 10
# Epoch 324 - Train loss: 2.91e+02 - Val loss: 2.06e+03 - ES count: 0
# Epoch 325 - Train loss: 2.89e+02 - Val loss: 2.89e+03 - ES count: 1
# Epoch 326 - Train loss: 2.97e+02 - Val loss: 2.39e+03 - ES count: 2
# Epoch 327 - Train loss: 2.67e+02 - Val loss: 2.7e+03 - ES count: 3
# Epoch 328 - Train loss: 2.72e+02 - Val loss: 2.48e+03 - ES count: 4
# Epoch 329 - Train loss: 2.74e+02 - Val loss: 2.38e+03 - ES count: 5
# Epoch 330 - Train loss: 2.97e+02 - Val loss: 2.58e+03 - ES count: 6
# Epoch 331 - Train loss: 2.69e+02 - Val loss: 3.48e+03 - ES count: 7
# Epoch 332 - Train loss: 2.77e+02 - Val loss: 2.87e+03 - ES count: 8
# Epoch 333 - Train loss: 3.06e+02 - Val loss: 2.59e+03 - ES count: 9
# Epoch 334 - Train loss: 2.84e+02 - Val loss: 2.42e+03 - ES count: 10
# Epoch 335 - Train loss: 2.76e+02 - Val loss: 3.1e+03 - ES count: 11
# Epoch 336 - Train loss: 2.82e+02 - Val loss: 2.59e+03 - ES count: 12
# Epoch 337 - Train loss: 2.78e+02 - Val loss: 2.53e+03 - ES count: 13
# Epoch 338 - Train loss: 2.74e+02 - Val loss: 2.36e+03 - ES count: 14
# Epoch 339 - Train loss: 2.77e+02 - Val loss: 2.22e+03 - ES count: 15
# Epoch 340 - Train loss: 2.9e+02 - Val loss: 3.41e+03 - ES count: 16
# Epoch 341 - Train loss: 2.81e+02 - Val loss: 2.92e+03 - ES count: 17
# Epoch 342 - Train loss: 2.96e+02 - Val loss: 2.65e+03 - ES count: 18
# Epoch 343 - Train loss: 2.68e+02 - Val loss: 2.98e+03 - ES count: 19
# Epoch 344 - Train loss: 2.65e+02 - Val loss: 2.6e+03 - ES count: 20
# Epoch 345 - Train loss: 2.71e+02 - Val loss: 2.69e+03 - ES count: 21
# Epoch 346 - Train loss: 2.72e+02 - Val loss: 2.82e+03 - ES count: 22
# Epoch 347 - Train loss: 2.83e+02 - Val loss: 3.11e+03 - ES count: 23
# Epoch 348 - Train loss: 2.84e+02 - Val loss: 2.17e+03 - ES count: 24
# Epoch 349 - Train loss: 2.79e+02 - Val loss: 2.54e+03 - ES count: 25
# Epoch 350 - Train loss: 2.77e+02 - Val loss: 2.7e+03 - ES count: 26
# Epoch 351 - Train loss: 2.64e+02 - Val loss: 2.6e+03 - ES count: 27
# Epoch 352 - Train loss: 2.85e+02 - Val loss: 2.12e+03 - ES count: 28
# Epoch 353 - Train loss: 2.66e+02 - Val loss: 3.1e+03 - ES count: 29

# %%
## Load best set of weights on test/validation set onto CPU for evaluation
prop_pnn = PropNet(max_val=max_val, D=D, M=M)

prop_pnn.load_state_dict(torch.load(project_dir /"src" / "outputs" / "weights" / "weights-50-40"))

train_preds_prop = eval_model(train_dataset, prop_pnn, label_type='z')
plot_preds(train_preds_prop, train_dataset, title="Same Day Nowcast Train Performance (PropNet)")

val_preds = eval_model(val_dataset, prop_pnn, label_type='z')
plot_preds(val_preds, val_dataset, title="Same Day Nowcast Validation Performance (PropNet)")

test_preds = eval_model(test_dataset, prop_pnn, label_type='z')
plot_preds(test_preds, test_dataset, title="Same Day Nowcast Test Performance (PropNet)")

# %%
early_stopper = EarlyStopper(patience=30, past_units=M, max_delay=D, weeks=False, future_obs=0, random_split=False, dow = True)
prop_net = PNN(max_val=max_val, D=D, M=M)
train(prop_net, num_epochs=400, train_loader=train_loader, val_loader=val_loader, early_stopper=early_stopper, loss_fct="nll", device = device, dow = True, label_type='z')
