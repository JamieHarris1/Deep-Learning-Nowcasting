# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import random
import datetime
from torch.utils.data import DataLoader, Dataset
import torch
sys.path.append(os.path.abspath('../src'))

from data_tools.data_utils import create_data_split

# %%
# Set seeds for batch shuffle and during training

def set_seed(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed = 123
set_seed(seed)

# %%
project_dir = project_dir = Path.cwd().parent
trunc_D = 40

create_data_split(
    start_year=2013,
    end_year=2020,
    D=trunc_D,
    data_folder_path = project_dir / "data",
    input_filename="DENGSP.csv",
    train_prop=0.7,
    val_prop=0.15,
    test_prop=0.15
)
# Out:
# /Users/jamieharris/Documents/GitHub/Imperial/Dengue-Nowcasting-Thesis/src/data_tools/data_utils.py:19: DtypeWarning: Columns (7,11,23,45,46,47,55,65,69,75,86,102) have mixed types. Specify dtype option on import or set low_memory=False.
#   dengdf_raw = pd.read_csv(input_data_path, index_col=0)

# %%
complete_df = pd.read_csv(project_dir / "data" / "model" / "complete_data.csv",
    parse_dates=True,
    date_format="%Y %b",
    index_col=0,
    dtype={"value": float},
)

train_df = pd.read_csv(project_dir / "data" / "model" / "training_data.csv",
    parse_dates=True,
    date_format="%Y %b",
    index_col=0,
    dtype={"value": float},
)

val_df = pd.read_csv(project_dir / "data" / "model" / "validation_data.csv",
    parse_dates=True,
    date_format="%Y %b",
    index_col=0,
    dtype={"value": float},
)
test_df = pd.read_csv(project_dir / "data" / "model" / "test_data.csv",
    parse_dates=True,
    date_format="%Y %b",
    index_col=0,
    dtype={"value": float},
)

# %%
class ReportingDataset(Dataset):
    # first available datapoint is index self.D - 1,
    # e.g D=40, then self.df[39] is first day with a reporting triangle of length 40 

    def __init__(self, df, D, max_val, label_type, device):
        self.D = D
        self.dates = pd.to_datetime(df.copy().index[self.D-1:])
        self.df = np.array(df.copy(), dtype = np.float32)
        self.max_val = max_val
        self.label_type = label_type
        self.device = device

        assert self.label_type in ("y", "z"), 'label_type must either be "y" or "z"'

    def __len__(self):
        return len(self.df) - self.D + 1


    def __getitem__(self, idx):
        t = idx + self.D
        obs = self.df[t-self.D: t]

        # Create observed reporting triangle
        mask = self.get_mask()
        obs_masked = obs.copy() / self.max_val
        obs_masked[~mask] = 0
        obs_masked = torch.tensor(obs_masked, dtype=torch.float32)
        obs_masked = obs_masked.to(self.device)

        # Get day of the week
        date = self.get_date(idx)
        dow = torch.tensor(date.weekday(), dtype=torch.int32)
        dow.to(self.device)
        
        if self.label_type == 'y':
            # Create y label
            y_label = torch.tensor(obs[self.D - 1, :].sum(), dtype=torch.float32)
            y_label.to(self.device)
            return (obs_masked, dow), y_label
        
        elif self.label_type == 'z':
            # Create z label
            z_label = torch.tensor(obs[self.D - 1, :], dtype=torch.float32)
            z_label.to(self.device)
            return (obs_masked, dow), z_label
            
    
    def get_mask(self):
        mask_matrix = np.ones(shape=(self.D, self.D), dtype=bool)
        for i in range(self.D):
            for j in range(self.D):
                if i + j > self.D - 1:
                    mask_matrix[i, j] = False
        return mask_matrix

    def get_date(self, idx):
        return self.dates[idx].date()
    
    def get_y(self, idx):
        t = idx + self.D
        return np.array(self.df[t-1].sum())

max_val = train_df.values.max()

# %% [markdown]
# Train NowcastPNN model using y directly for benchmark

# %%
device = "cpu"

complete_dataset = ReportingDataset(complete_df, 40, max_val, label_type='y', device=device)
train_dataset = ReportingDataset(train_df, 40, max_val, label_type='y', device=device)
val_dataset = ReportingDataset(val_df, 40, max_val, label_type='y', device=device)
test_dataset = ReportingDataset(test_df, 40, max_val, label_type='y', device=device)

# %%
####### Potential to add unit tests and asserts here ###########


# Check dataset working as anticipated

# original df
print(train_df.iloc[39].sum())
print(train_df.index[39])

# dataset obj
print(train_dataset.get_y(0))
print(train_dataset.get_date(0))
print(train_dataset.__getitem__(0)[1].sum())

# check mask
train_dataset.__getitem__(0)[0]
# Out:
# 4650
# 2013-03-20
# 4650.0
# 2013-03-20
# tensor(4650.)
# (tensor([[3.6846e-02, 4.8898e-02, 5.3030e-02,  ..., 3.4435e-04, 0.0000e+00,
#           0.0000e+00],
#          [3.7190e-02, 6.2672e-02, 4.5110e-02,  ..., 3.4435e-04, 3.4435e-04,
#           0.0000e+00],
#          [4.3733e-02, 6.3361e-02, 6.3361e-02,  ..., 3.4435e-04, 0.0000e+00,
#           0.0000e+00],
#          ...,
#          [1.8216e-01, 3.3643e-01, 2.8512e-01,  ..., 0.0000e+00, 0.0000e+00,
#           0.0000e+00],
#          [1.7528e-01, 3.7225e-01, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#           0.0000e+00],
#          [1.9938e-01, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#           0.0000e+00]]),
#  tensor(2, dtype=torch.int32))

# %%
# Create dataloaders, shuffle trainign data for better training
g = torch.Generator()
g.manual_seed(seed)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, generator=g)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
train_dataset.__len__()
# Out:
# 1991

# %%
train_dataset.__len__()
# Out:
# 1991

# %%
print(train_dataset.dates)
# Out:
# DatetimeIndex(['2013-03-20', '2013-03-21', '2013-03-22', '2013-03-23',
#                '2013-03-24', '2013-03-25', '2013-03-26', '2013-03-27',
#                '2013-03-28', '2013-03-29',
#                ...
#                '2018-08-22', '2018-08-23', '2018-08-24', '2018-08-25',
#                '2018-08-26', '2018-08-27', '2018-08-28', '2018-08-29',
#                '2018-08-30', '2018-08-31'],
#               dtype='datetime64[ns]', name='Date_Symptoms', length=1991, freq=None)

# %%
from PNN.train_utils import train, EarlyStopper
from PNN.NowcastPNN import NowcastPNNDOW

early_stopper = EarlyStopper(patience=30, past_units=40, max_delay=40, weeks=False, future_obs=0, random_split=False, dow = True)
nowcast_pnn = NowcastPNNDOW(past_units=40, max_delay=40, conv_channels=[16, 1], hidden_units=[16, 8], dropout_probs=[0.3, 0.1], device=device)

train(nowcast_pnn, num_epochs=200, train_loader=train_loader, val_loader=val_loader, early_stopper=early_stopper, loss_fct="nll", device = device, dow = True)
# Out:
# Epoch 1 - Train loss: 1.98e+05 - Val loss: 2.26e+06 - ES count: 0
# Epoch 2 - Train loss: 1.83e+05 - Val loss: 2.06e+06 - ES count: 0
# Epoch 3 - Train loss: 1.73e+05 - Val loss: 1.92e+06 - ES count: 0
# Epoch 4 - Train loss: 1.63e+05 - Val loss: 1.8e+06 - ES count: 0
# Epoch 5 - Train loss: 1.53e+05 - Val loss: 1.63e+06 - ES count: 0
# Epoch 6 - Train loss: 1.43e+05 - Val loss: 1.67e+06 - ES count: 1
# Epoch 7 - Train loss: 1.32e+05 - Val loss: 1.43e+06 - ES count: 0
# Epoch 8 - Train loss: 1.21e+05 - Val loss: 1.47e+06 - ES count: 1
# Epoch 9 - Train loss: 1.09e+05 - Val loss: 1.2e+06 - ES count: 0
# Epoch 10 - Train loss: 9.73e+04 - Val loss: 9.51e+05 - ES count: 0
# Epoch 11 - Train loss: 8.67e+04 - Val loss: 8.7e+05 - ES count: 0
# Epoch 12 - Train loss: 7.66e+04 - Val loss: 7.72e+05 - ES count: 0
# Epoch 13 - Train loss: 6.68e+04 - Val loss: 6.6e+05 - ES count: 0
# Epoch 14 - Train loss: 5.81e+04 - Val loss: 5.97e+05 - ES count: 0
# Epoch 15 - Train loss: 5.01e+04 - Val loss: 4.96e+05 - ES count: 0
# Epoch 16 - Train loss: 4.34e+04 - Val loss: 3.97e+05 - ES count: 0
# Epoch 17 - Train loss: 3.77e+04 - Val loss: 3.83e+05 - ES count: 0
# Epoch 18 - Train loss: 3.21e+04 - Val loss: 2.54e+05 - ES count: 0
# Epoch 19 - Train loss: 2.77e+04 - Val loss: 2.38e+05 - ES count: 0
# Epoch 20 - Train loss: 2.42e+04 - Val loss: 2.03e+05 - ES count: 0
# Epoch 21 - Train loss: 2.07e+04 - Val loss: 1.84e+05 - ES count: 0
# Epoch 22 - Train loss: 1.77e+04 - Val loss: 1.56e+05 - ES count: 0
# Epoch 23 - Train loss: 1.55e+04 - Val loss: 9.12e+04 - ES count: 0
# Epoch 24 - Train loss: 1.37e+04 - Val loss: 1.05e+05 - ES count: 1
# Epoch 25 - Train loss: 1.18e+04 - Val loss: 1.07e+05 - ES count: 2
# Epoch 26 - Train loss: 1.07e+04 - Val loss: 6.6e+04 - ES count: 0
# Epoch 27 - Train loss: 9.33e+03 - Val loss: 4.82e+04 - ES count: 0
# Epoch 28 - Train loss: 8.08e+03 - Val loss: 7.7e+04 - ES count: 1
# Epoch 29 - Train loss: 7.41e+03 - Val loss: 5.02e+04 - ES count: 2
# Epoch 30 - Train loss: 6.74e+03 - Val loss: 5.27e+04 - ES count: 3
# Epoch 31 - Train loss: 5.95e+03 - Val loss: 3.78e+04 - ES count: 0
# Epoch 32 - Train loss: 5.95e+03 - Val loss: 3e+04 - ES count: 0
# Epoch 33 - Train loss: 5.12e+03 - Val loss: 3.18e+04 - ES count: 1
# Epoch 34 - Train loss: 5.16e+03 - Val loss: 2.69e+04 - ES count: 0
# Epoch 35 - Train loss: 4.39e+03 - Val loss: 1.99e+04 - ES count: 0
# Epoch 36 - Train loss: 4.21e+03 - Val loss: 2.58e+04 - ES count: 1
# Epoch 37 - Train loss: 3.97e+03 - Val loss: 2.22e+04 - ES count: 2
# Epoch 38 - Train loss: 3.87e+03 - Val loss: 2.66e+04 - ES count: 3
# Epoch 39 - Train loss: 3.56e+03 - Val loss: 2.13e+04 - ES count: 4
# Epoch 40 - Train loss: 3.4e+03 - Val loss: 2.55e+04 - ES count: 5
# Epoch 41 - Train loss: 3.26e+03 - Val loss: 1.7e+04 - ES count: 0
# Epoch 42 - Train loss: 3.36e+03 - Val loss: 2.13e+04 - ES count: 1
# Epoch 43 - Train loss: 3e+03 - Val loss: 2.16e+04 - ES count: 2
# Epoch 44 - Train loss: 3.07e+03 - Val loss: 1.8e+04 - ES count: 3
# Epoch 45 - Train loss: 2.79e+03 - Val loss: 2.26e+04 - ES count: 4
# Epoch 46 - Train loss: 3.26e+03 - Val loss: 1.63e+04 - ES count: 0
# Epoch 47 - Train loss: 2.49e+03 - Val loss: 1.47e+04 - ES count: 0
# Epoch 48 - Train loss: 2.58e+03 - Val loss: 1.98e+04 - ES count: 1
# Epoch 49 - Train loss: 2.32e+03 - Val loss: 2.31e+04 - ES count: 2
# Epoch 50 - Train loss: 2.33e+03 - Val loss: 2.07e+04 - ES count: 3
# Epoch 51 - Train loss: 2.53e+03 - Val loss: 2.08e+04 - ES count: 4
# Epoch 52 - Train loss: 2.39e+03 - Val loss: 3.1e+04 - ES count: 5
# Epoch 53 - Train loss: 2.35e+03 - Val loss: 2e+04 - ES count: 6
# Epoch 54 - Train loss: 2.47e+03 - Val loss: 3.58e+04 - ES count: 7
# Epoch 55 - Train loss: 2.5e+03 - Val loss: 3.12e+04 - ES count: 8
# Epoch 56 - Train loss: 2.48e+03 - Val loss: 2.04e+04 - ES count: 9
# Epoch 57 - Train loss: 2.57e+03 - Val loss: 2.63e+04 - ES count: 10
# Epoch 58 - Train loss: 2.47e+03 - Val loss: 1.89e+04 - ES count: 11
# Epoch 59 - Train loss: 2.57e+03 - Val loss: 2.04e+04 - ES count: 12
# Epoch 60 - Train loss: 2.16e+03 - Val loss: 2.07e+04 - ES count: 13
# Epoch 61 - Train loss: 2.46e+03 - Val loss: 1.81e+04 - ES count: 14
# Epoch 62 - Train loss: 2.31e+03 - Val loss: 1.34e+04 - ES count: 0
# Epoch 63 - Train loss: 2.09e+03 - Val loss: 1.57e+04 - ES count: 1
# Epoch 64 - Train loss: 2.33e+03 - Val loss: 1.43e+04 - ES count: 2
# Epoch 65 - Train loss: 2.39e+03 - Val loss: 2.44e+04 - ES count: 3
# Epoch 66 - Train loss: 2.28e+03 - Val loss: 1.88e+04 - ES count: 4
# Epoch 67 - Train loss: 2.06e+03 - Val loss: 2.2e+04 - ES count: 5
# Epoch 68 - Train loss: 2.31e+03 - Val loss: 1.34e+04 - ES count: 5
# Epoch 69 - Train loss: 2.24e+03 - Val loss: 2.13e+04 - ES count: 6
# Epoch 70 - Train loss: 2.12e+03 - Val loss: 2.24e+04 - ES count: 7
# Epoch 71 - Train loss: 2.18e+03 - Val loss: 1.96e+04 - ES count: 8
# Epoch 72 - Train loss: 2.08e+03 - Val loss: 1.91e+04 - ES count: 9
# Epoch 73 - Train loss: 2.13e+03 - Val loss: 1.57e+04 - ES count: 10
# Epoch 74 - Train loss: 2.26e+03 - Val loss: 1.24e+04 - ES count: 0
# Epoch 75 - Train loss: 2.25e+03 - Val loss: 1.64e+04 - ES count: 1
# Epoch 76 - Train loss: 2.17e+03 - Val loss: 1.94e+04 - ES count: 2
# Epoch 77 - Train loss: 2.19e+03 - Val loss: 2.32e+04 - ES count: 3
# Epoch 78 - Train loss: 2.1e+03 - Val loss: 1e+04 - ES count: 0
# Epoch 79 - Train loss: 2.11e+03 - Val loss: 3.58e+04 - ES count: 1
# Epoch 80 - Train loss: 2e+03 - Val loss: 1.84e+04 - ES count: 2
# Epoch 81 - Train loss: 2.06e+03 - Val loss: 2.61e+04 - ES count: 3
# Epoch 82 - Train loss: 2.15e+03 - Val loss: 2.56e+04 - ES count: 4
# Epoch 83 - Train loss: 1.92e+03 - Val loss: 1.92e+04 - ES count: 5
# Epoch 84 - Train loss: 2.18e+03 - Val loss: 1.55e+04 - ES count: 6
# Epoch 85 - Train loss: 1.8e+03 - Val loss: 2.38e+04 - ES count: 7
# Epoch 86 - Train loss: 2.08e+03 - Val loss: 1.32e+04 - ES count: 8
# Epoch 87 - Train loss: 2.09e+03 - Val loss: 1.86e+04 - ES count: 9
# Epoch 88 - Train loss: 1.9e+03 - Val loss: 2.05e+04 - ES count: 10
# Epoch 89 - Train loss: 1.87e+03 - Val loss: 1.04e+04 - ES count: 11
# Epoch 90 - Train loss: 1.82e+03 - Val loss: 1.71e+04 - ES count: 12
# Epoch 91 - Train loss: 1.74e+03 - Val loss: 2.46e+04 - ES count: 13
# Epoch 92 - Train loss: 1.97e+03 - Val loss: 2.25e+04 - ES count: 14
# Epoch 93 - Train loss: 2.14e+03 - Val loss: 1.68e+04 - ES count: 15
# Epoch 94 - Train loss: 1.81e+03 - Val loss: 1.59e+04 - ES count: 16
# Epoch 95 - Train loss: 1.9e+03 - Val loss: 3.46e+04 - ES count: 17
# Epoch 96 - Train loss: 1.97e+03 - Val loss: 1.43e+04 - ES count: 18
# Epoch 97 - Train loss: 2.02e+03 - Val loss: 2.69e+04 - ES count: 19
# Epoch 98 - Train loss: 2e+03 - Val loss: 1.98e+04 - ES count: 20
# Epoch 99 - Train loss: 1.84e+03 - Val loss: 3.57e+04 - ES count: 21
# Epoch 100 - Train loss: 2.14e+03 - Val loss: 1.37e+04 - ES count: 22
# Epoch 101 - Train loss: 1.83e+03 - Val loss: 2.67e+04 - ES count: 23
# Epoch 102 - Train loss: 1.82e+03 - Val loss: 1.61e+04 - ES count: 24
# Epoch 103 - Train loss: 2.05e+03 - Val loss: 3.97e+04 - ES count: 25
# Epoch 104 - Train loss: 1.63e+03 - Val loss: 2.68e+04 - ES count: 26
# Epoch 105 - Train loss: 1.89e+03 - Val loss: 3.76e+04 - ES count: 27
# Epoch 106 - Train loss: 1.74e+03 - Val loss: 1.73e+04 - ES count: 28
# Epoch 107 - Train loss: 1.64e+03 - Val loss: 1.17e+04 - ES count: 29

# %%
## Load best set of weights on test/validation set onto CPU for evaluation
nowcast_pnn = NowcastPNNDOW(past_units=40, max_delay=40, conv_channels=[16, 1], hidden_units=[16, 8], dropout_probs=[0.3, 0.1], device="cpu")

nowcast_pnn.load_state_dict(torch.load(project_dir /"src" / "outputs" / "weights" / "weights-40-40"))
# Out:
# <All keys matched successfully>

# %%
def eval_model(dataset, model, label_type):
    eval_loader = DataLoader(dataset, batch_size=dataset.__len__(), shuffle=False)

    # Put model in eval mode with dropout active
    model.eval()
    model.drop1.train()
    model.drop2.train()

    (matrix, dow), label = next(iter(eval_loader))
    matrix = matrix.to("cpu")
    dow = dow.to("cpu")
    model = model.to("cpu")

    n_samples = 1000
    preds = np.zeros(shape=(dataset.__len__(), n_samples))
    for i in range(n_samples):
        samples = model(matrix, dow).sample().numpy()
        if label_type == 'z':
            samples = samples.sum(axis=-1)
        preds[:, i] = samples

    return preds

def plot_preds(preds, dataset, other_preds=False, other_preds_label=False):
    preds_median = np.quantile(preds, 0.5, axis=1)
    y_true = [dataset.get_y(idx) for idx in range(dataset.__len__())]
    dates = pd.to_datetime(dataset.dates)
    plt.plot(dates, preds_median, label='preds')
    if other_preds is not False:
        plt.plot(dates, other_preds, label=other_preds_label)
    plt.plot(dates, y_true, label='y')
    plt.legend()
    plt.xticks(rotation=45)
    plt.show()

# %%
train_preds = eval_model(train_dataset, nowcast_pnn, label_type='y')
plot_preds(train_preds, train_dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 train_preds = eval_model(train_dataset, nowcast_pnn, label_type='y')
#       2 plot_preds(train_preds, train_dataset)
#
# NameError: name 'eval_model' is not defined

# %%
val_preds = eval_model(val_dataset, nowcast_pnn, label_type='y')
plot_preds(val_preds, val_dataset)

# %%
print(len(test_dataset))
# Out:
# 389

# %%
test_preds = eval_model(test_dataset, nowcast_pnn, label_type='y')
plot_preds(test_preds, test_dataset)

# %% [markdown]
# Prop PNN

# %%
device = "cpu"

complete_dataset = ReportingDataset(complete_df, 40, max_val, label_type='z', device=device)
train_dataset = ReportingDataset(train_df, 40, max_val, label_type='z', device=device)
val_dataset = ReportingDataset(val_df, 40, max_val, label_type='z', device=device)
test_dataset = ReportingDataset(test_df, 40, max_val, label_type='z', device=device)

# Create dataloaders, shuffle trainign data for better training
g = torch.Generator()
g.manual_seed(seed)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, generator=g)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
from PNN.train_utils import train, EarlyStopper
from PNN.NowcastPNN import PropPNN

early_stopper = EarlyStopper(patience=30, past_units=40, max_delay=40, weeks=False, future_obs=0, random_split=False, dow = True)
prop_pnn = PropPNN(max_val=max_val, past_units=40, max_delay=40, conv_channels=[16, 1], hidden_units=[16, 8], dropout_probs=[0.3, 0.1], device=device)

# %%
train(prop_pnn, num_epochs=400, train_loader=train_loader, val_loader=val_loader, early_stopper=early_stopper, loss_fct="nll", device = device, dow = True, label_type='z', alpha=0.5)
# Out:
# Epoch 1 - Train loss: 2.37e+06 - Val loss: 2.43e+07 - ES count: 0
# Epoch 2 - Train loss: 1.76e+06 - Val loss: 1.25e+07 - ES count: 0
# Epoch 3 - Train loss: 1.54e+06 - Val loss: 1.14e+07 - ES count: 0
# Epoch 4 - Train loss: 1.34e+06 - Val loss: 9.54e+06 - ES count: 0
# Epoch 5 - Train loss: 1.17e+06 - Val loss: 9.2e+06 - ES count: 0
# Epoch 6 - Train loss: 1.16e+06 - Val loss: 8.54e+06 - ES count: 0
# Epoch 7 - Train loss: 1.03e+06 - Val loss: 7.34e+06 - ES count: 0
# Epoch 8 - Train loss: 9.88e+05 - Val loss: 9.57e+06 - ES count: 1
# Epoch 9 - Train loss: 9.24e+05 - Val loss: 6.61e+06 - ES count: 0
# Epoch 10 - Train loss: 8.07e+05 - Val loss: 5.56e+06 - ES count: 0
# Epoch 11 - Train loss: 7.15e+05 - Val loss: 5.07e+06 - ES count: 0
# Epoch 12 - Train loss: 7.49e+05 - Val loss: 4.99e+06 - ES count: 0
# Epoch 13 - Train loss: 6.69e+05 - Val loss: 5.59e+06 - ES count: 1
# Epoch 14 - Train loss: 6.11e+05 - Val loss: 4.83e+06 - ES count: 0
# Epoch 15 - Train loss: 5.98e+05 - Val loss: 4.17e+06 - ES count: 0
# Epoch 16 - Train loss: 5.18e+05 - Val loss: 2.56e+06 - ES count: 0
# Epoch 17 - Train loss: 5.47e+05 - Val loss: 4.93e+06 - ES count: 1
# Epoch 18 - Train loss: 4.32e+05 - Val loss: 3.12e+06 - ES count: 2
# Epoch 19 - Train loss: 4.19e+05 - Val loss: 2.97e+06 - ES count: 3
# Epoch 20 - Train loss: 4.29e+05 - Val loss: 2.95e+06 - ES count: 4
# Epoch 21 - Train loss: 4.11e+05 - Val loss: 2.97e+06 - ES count: 5
# Epoch 22 - Train loss: 3.23e+05 - Val loss: 3.07e+06 - ES count: 6
# Epoch 23 - Train loss: 3.41e+05 - Val loss: 2.27e+06 - ES count: 0
# Epoch 24 - Train loss: 3.5e+05 - Val loss: 2.34e+06 - ES count: 1
# Epoch 25 - Train loss: 3.18e+05 - Val loss: 2.26e+06 - ES count: 0
# Epoch 26 - Train loss: 2.96e+05 - Val loss: 3.45e+06 - ES count: 1
# Epoch 27 - Train loss: 2.73e+05 - Val loss: 2.65e+06 - ES count: 2
# Epoch 28 - Train loss: 2.41e+05 - Val loss: 1.86e+06 - ES count: 0
# Epoch 29 - Train loss: 2.67e+05 - Val loss: 1.65e+06 - ES count: 0
# Epoch 30 - Train loss: 2.43e+05 - Val loss: 1.63e+06 - ES count: 0
# Epoch 31 - Train loss: 2.34e+05 - Val loss: 1.51e+06 - ES count: 0
# Epoch 32 - Train loss: 2.49e+05 - Val loss: 1.33e+06 - ES count: 0
# Epoch 33 - Train loss: 2.02e+05 - Val loss: 1.64e+06 - ES count: 1
# Epoch 34 - Train loss: 1.9e+05 - Val loss: 3.17e+06 - ES count: 2
# Epoch 35 - Train loss: 2.12e+05 - Val loss: 1.21e+06 - ES count: 0
# Epoch 36 - Train loss: 2.18e+05 - Val loss: 1.24e+06 - ES count: 1
# Epoch 37 - Train loss: 2.24e+05 - Val loss: 1.13e+06 - ES count: 0
# Epoch 38 - Train loss: 2.02e+05 - Val loss: 2.54e+06 - ES count: 1
# Epoch 39 - Train loss: 1.79e+05 - Val loss: 1.28e+06 - ES count: 2
# Epoch 40 - Train loss: 1.69e+05 - Val loss: 2.2e+06 - ES count: 3
# Epoch 41 - Train loss: 1.89e+05 - Val loss: 9.43e+05 - ES count: 0
# Epoch 42 - Train loss: 1.76e+05 - Val loss: 1.67e+06 - ES count: 1
# Epoch 43 - Train loss: 1.47e+05 - Val loss: 1.06e+06 - ES count: 2
# Epoch 44 - Train loss: 1.74e+05 - Val loss: 1.04e+06 - ES count: 3
# Epoch 45 - Train loss: 1.59e+05 - Val loss: 9.3e+05 - ES count: 0
# Epoch 46 - Train loss: 1.68e+05 - Val loss: 1.99e+06 - ES count: 1
# Epoch 47 - Train loss: 1.81e+05 - Val loss: 1.05e+06 - ES count: 2
# Epoch 48 - Train loss: 1.65e+05 - Val loss: 1.69e+06 - ES count: 3
# Epoch 49 - Train loss: 1.48e+05 - Val loss: 1.53e+06 - ES count: 4
# Epoch 50 - Train loss: 1.43e+05 - Val loss: 1.63e+06 - ES count: 5
# Epoch 51 - Train loss: 1.67e+05 - Val loss: 2.35e+06 - ES count: 6
# Epoch 52 - Train loss: 1.32e+05 - Val loss: 1.63e+06 - ES count: 7
# Epoch 53 - Train loss: 1.22e+05 - Val loss: 1.47e+06 - ES count: 8
# Epoch 54 - Train loss: 1.34e+05 - Val loss: 1.48e+06 - ES count: 9
# Epoch 55 - Train loss: 1.53e+05 - Val loss: 2.45e+06 - ES count: 10
# Epoch 56 - Train loss: 1.35e+05 - Val loss: 1.18e+06 - ES count: 11
# Epoch 57 - Train loss: 1.52e+05 - Val loss: 2.02e+06 - ES count: 12
# Epoch 58 - Train loss: 1.57e+05 - Val loss: 1.27e+06 - ES count: 13
# Epoch 59 - Train loss: 1.62e+05 - Val loss: 1.03e+06 - ES count: 14
# Epoch 60 - Train loss: 1.25e+05 - Val loss: 1.76e+06 - ES count: 15
# Epoch 61 - Train loss: 1.25e+05 - Val loss: 2e+06 - ES count: 16
# Epoch 62 - Train loss: 1.33e+05 - Val loss: 1.15e+06 - ES count: 17
# Epoch 63 - Train loss: 1.22e+05 - Val loss: 1.39e+06 - ES count: 18
# Epoch 64 - Train loss: 1.25e+05 - Val loss: 1.09e+06 - ES count: 19
# Epoch 65 - Train loss: 1.23e+05 - Val loss: 1.56e+06 - ES count: 20
# Epoch 66 - Train loss: 1.38e+05 - Val loss: 8.15e+05 - ES count: 0
# Epoch 67 - Train loss: 1.4e+05 - Val loss: 1.95e+06 - ES count: 1
# Epoch 68 - Train loss: 1.38e+05 - Val loss: 7.55e+05 - ES count: 0
# Epoch 69 - Train loss: 1.32e+05 - Val loss: 2.14e+06 - ES count: 1
# Epoch 70 - Train loss: 1.11e+05 - Val loss: 1.65e+06 - ES count: 2
# Epoch 71 - Train loss: 1.33e+05 - Val loss: 2.44e+06 - ES count: 3
# Epoch 72 - Train loss: 1.07e+05 - Val loss: 1.13e+06 - ES count: 4
# Epoch 73 - Train loss: 1.07e+05 - Val loss: 1.06e+06 - ES count: 5
# Epoch 74 - Train loss: 1.08e+05 - Val loss: 2e+06 - ES count: 6
# Epoch 75 - Train loss: 1.12e+05 - Val loss: 2.84e+06 - ES count: 7
# Epoch 76 - Train loss: 1.09e+05 - Val loss: 1.54e+06 - ES count: 8
# Epoch 77 - Train loss: 8.27e+04 - Val loss: 1.74e+06 - ES count: 9
# Epoch 78 - Train loss: 1.34e+05 - Val loss: 9.16e+05 - ES count: 10
# Epoch 79 - Train loss: 1.27e+05 - Val loss: 2.83e+06 - ES count: 11
# Epoch 80 - Train loss: 1.13e+05 - Val loss: 1.8e+06 - ES count: 12
# Epoch 81 - Train loss: 1.36e+05 - Val loss: 1.39e+06 - ES count: 13
# Epoch 82 - Train loss: 1.08e+05 - Val loss: 1.49e+06 - ES count: 14
# Epoch 83 - Train loss: 1.01e+05 - Val loss: 2.02e+06 - ES count: 15
# Epoch 84 - Train loss: 9.55e+04 - Val loss: 2.01e+06 - ES count: 16
# Epoch 85 - Train loss: 1.12e+05 - Val loss: 2.79e+06 - ES count: 17
# Epoch 86 - Train loss: 1.02e+05 - Val loss: 2.1e+06 - ES count: 18
# Epoch 87 - Train loss: 1.04e+05 - Val loss: 2.55e+06 - ES count: 19
# Epoch 88 - Train loss: 1.02e+05 - Val loss: 1.51e+06 - ES count: 20
# Epoch 89 - Train loss: 1.1e+05 - Val loss: 1.03e+06 - ES count: 21
# Epoch 90 - Train loss: 1.06e+05 - Val loss: 6.99e+05 - ES count: 0
# Epoch 91 - Train loss: 1.16e+05 - Val loss: 2.13e+06 - ES count: 1
# Epoch 92 - Train loss: 1.07e+05 - Val loss: 1.54e+06 - ES count: 2
# Epoch 93 - Train loss: 1.22e+05 - Val loss: 1.84e+06 - ES count: 3
# Epoch 94 - Train loss: 1.04e+05 - Val loss: 2.01e+06 - ES count: 4
# Epoch 95 - Train loss: 1.11e+05 - Val loss: 3.7e+06 - ES count: 5
# Epoch 96 - Train loss: 1.03e+05 - Val loss: 3.03e+06 - ES count: 6
# Epoch 97 - Train loss: 1.07e+05 - Val loss: 1.48e+06 - ES count: 7
# Epoch 98 - Train loss: 1.02e+05 - Val loss: 1.4e+06 - ES count: 8
# Epoch 99 - Train loss: 9.65e+04 - Val loss: 2.07e+06 - ES count: 9
# Epoch 100 - Train loss: 1.06e+05 - Val loss: 1.61e+06 - ES count: 10
# Epoch 101 - Train loss: 8.83e+04 - Val loss: 2.55e+06 - ES count: 11
# Epoch 102 - Train loss: 9.86e+04 - Val loss: 1.17e+06 - ES count: 12
# Epoch 103 - Train loss: 1.28e+05 - Val loss: 2.73e+06 - ES count: 13
# Epoch 104 - Train loss: 1.07e+05 - Val loss: 4.62e+06 - ES count: 14
# Epoch 105 - Train loss: 1.06e+05 - Val loss: 2.14e+06 - ES count: 15
# Epoch 106 - Train loss: 9.35e+04 - Val loss: 2.55e+06 - ES count: 16
# Epoch 107 - Train loss: 9.95e+04 - Val loss: 1.76e+06 - ES count: 17
# Epoch 108 - Train loss: 9.12e+04 - Val loss: 1.9e+06 - ES count: 18
# Epoch 109 - Train loss: 9.58e+04 - Val loss: 2.13e+06 - ES count: 19
# Epoch 110 - Train loss: 9.07e+04 - Val loss: 2.27e+06 - ES count: 20
# Epoch 111 - Train loss: 9.49e+04 - Val loss: 2.32e+06 - ES count: 21
# Epoch 112 - Train loss: 8.88e+04 - Val loss: 1.67e+06 - ES count: 22
# Epoch 113 - Train loss: 1.04e+05 - Val loss: 1.56e+06 - ES count: 23
# Epoch 114 - Train loss: 8.19e+04 - Val loss: 8.37e+05 - ES count: 24
# Epoch 115 - Train loss: 8.84e+04 - Val loss: 2.74e+06 - ES count: 25
# Epoch 116 - Train loss: 9.57e+04 - Val loss: 1.78e+06 - ES count: 26
# Epoch 117 - Train loss: 8.7e+04 - Val loss: 2.11e+06 - ES count: 27
# Epoch 118 - Train loss: 8.13e+04 - Val loss: 1.91e+06 - ES count: 28
# Epoch 119 - Train loss: 9.34e+04 - Val loss: 1.94e+06 - ES count: 29

# %%
## Load best set of weights on test/validation set onto CPU for evaluation
prop_pnn = PropPNN(max_val=max_val, past_units=40, max_delay=40, conv_channels=[16, 1], hidden_units=[16, 8], dropout_probs=[0.3, 0.1], device="cpu")

prop_pnn.load_state_dict(torch.load(project_dir /"src" / "outputs" / "weights" / "weights-40-40"))

train_preds_prop = eval_model(train_dataset, prop_pnn, label_type='z')
plot_preds(train_preds_prop, train_dataset)

# %%
val_preds = eval_model(val_dataset, prop_pnn, label_type='z')
plot_preds(val_preds, val_dataset)

# %%
test_preds = eval_model(test_dataset, prop_pnn, label_type='z')
plot_preds(test_preds, test_dataset)
