# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


D = 20

project_dir = Path.cwd().parent
train_df = pd.read_csv(project_dir / "data" / "model" / "training_data.csv",
    parse_dates=True,
    date_format="%Y %b",
    index_col=0,
    dtype={"value": float},
)


train_df['y'] = train_df.sum(axis=1)
train_df.index = pd.to_datetime(train_df.index)
train_df.index.freq = train_df.index.inferred_freq

train_df
# Out:
#                delay_0  delay_1  delay_2  delay_3  delay_4  delay_5  delay_6  \
# Date_Symptoms
# 2013-01-21         138      184      137      129      106       14        7
# 2013-01-22         127      162      148       98       26       19       97
# 2013-01-23         102      222      138       44       31      107       77
# 2013-01-24         181      188       65       43      149       93       95
# 2013-01-25         106       86       48      192      104      110       91
# ...                ...      ...      ...      ...      ...      ...      ...
# 2018-07-26          10       16        7        8       14       11        4
# 2018-07-27           8        7        6       26        9       14        4
# 2018-07-28           4        4       16       19       10        5       10
# 2018-07-29           9       20       17       15       14        7        3
# 2018-07-30          14       20       17       13       11        2        2
#
#                delay_7  delay_8  delay_9  ...  delay_11  delay_12  delay_13  \
# Date_Symptoms                             ...
# 2013-01-21         107       42       30  ...        19         1         0
# 2013-01-22          72       36       30  ...         1         1        13
# 2013-01-23          75       41       27  ...         0        14         6
# 2013-01-24          65       37        3  ...        18        13         8
# 2013-01-25          75        6        0  ...        20        15         9
# ...                ...      ...      ...  ...       ...       ...       ...
# 2018-07-26           6        1        1  ...         4         2         3
# 2018-07-27           6        1        1  ...         1         2         1
# 2018-07-28           3        1        5  ...         1         2         0
# 2018-07-29           1        3        5  ...         4         0         0
# 2018-07-30          12        5        3  ...         0         0         0
#
#                delay_14  delay_15  delay_16  delay_17  delay_18  delay_19    y
# Date_Symptoms
# 2013-01-21           13         5         6         3         1         0  957
# 2013-01-22           13         5         4         1         0         1  864
# 2013-01-23            7         5         3         0         0         0  904
# 2013-01-24            6         5         0         0         0         0  969
# 2013-01-25            4         2         0         0         0         0  909
# ...                 ...       ...       ...       ...       ...       ...  ...
# 2018-07-26            3         1         0         0         0         0   91
# 2018-07-27            1         0         0         0         0         1   89
# 2018-07-28            0         0         1         0         2         0   86
# 2018-07-29            0         0         0         0         0         0  102
# 2018-07-30            1         2         0         0         0         0  104
#
# [2017 rows x 21 columns]

# %%
N = len(train_df) - D + 1
reporting_matrices = np.empty((N, D, D))

def mask_matrix(matrix):
        masked_matrix = matrix.copy()
        for i in range(D):
            for j in range(D):
                if i + j > D - 1:
                     masked_matrix[i, j] = 0
        return  masked_matrix

for i in range(N):
    t = i + D
    delay_matrix = train_df.copy().drop('y', axis=1)
    delay_matrix = np.array(delay_matrix.iloc[t - D : t].values)
    masked_delay_matrix = mask_matrix(delay_matrix)

    reporting_matrices[i] = masked_delay_matrix
