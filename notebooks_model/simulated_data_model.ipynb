# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os
import sys
import torch
from torch.utils.data import DataLoader, Dataset
from properscoring import crps_ensemble
import random




sys.path.append(os.path.abspath('../src'))
project_dir = Path.cwd().parent

from data_tools.data_utils import SimulateSero, PartialCountDataset, TrueCountDataset
from model_tools.train_utils import BaseTrain, SeroTrain, DirectTrain
from model_tools.models import SimSero, DirectSero
from model_tools.evaluation import eval_sero_pnn, plot_sero_pnn_preds, eval_pnn, eval_direct_sero

start_year = 2018
end_year = 2023
data_split = [0.7, 0.15, 0.15]
seed = 123

D = 40
M = 50
T = 40
Q = 40
N = 4


# 123, 2019, 2023, 15

def set_seed(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
# Simulate Data
# True counts * Constant sero prop vec * constant delay vec from average across world samples
p_sero = np.array([0.9, 0.0, 0.05, 0.05])
sero_all = ["DENV-1", "DENV-2", "DENV-3", "DENV-4"]



delays_df = pd.read_csv(project_dir / "data" / "transformed" / "DENG_delays.csv")
delays_df = delays_df.set_index("Collection date")
delays_df.index = pd.to_datetime(delays_df.index)

y_true = delays_df.sum(1)[:-2]
y_true_df = y_true.groupby(y_true.index.to_period("M")).sum()
y_true = np.array(y_true_df)
const = 10*np.ones_like(y_true)

denv_df = pd.read_csv(project_dir / "data" / "transformed" / "denv_df.csv")

denv_df = denv_df[denv_df['Delay'] < 60]

# If your original denv_df dates are datetime
denv_df['Collection date'] = pd.to_datetime(denv_df['Collection date'])

start_month = pd.to_datetime(delays_df.index.min())
end_month = pd.to_datetime(delays_df.index.max())

# Create a DataFrame of month start dates as datetime (not Period)
dates = pd.DataFrame({
    "Collection date": pd.date_range(start=start_month, end=end_month, freq='MS')
})

df = denv_df[denv_df['Sero'] == "DENV-1"] \
    .groupby(['Sero', 'Collection date', 'Delay']) \
    .size() \
    .reset_index(name='count')

df = df.pivot(index='Collection date', columns='Delay', values='count')

# Ensure df.index is datetime as well
df.index = pd.to_datetime(df.index)

p_delay = np.array(df.fillna(0).mean(0) / df.fillna(0).mean(0).sum())

p_sero = p_sero[:, np.newaxis, np.newaxis]   # shape (S,1,1)
const = const[np.newaxis, :, np.newaxis]  # shape (1,T,1)
p_delay = p_delay[np.newaxis, np.newaxis, :Q]  # shape (1,1,D)

# multiply to get (S,T,D)
sero_tensor = p_sero * const * p_delay
sero_tensor = sero_tensor.round()
for s,sero in enumerate(sero_all):
    sero_df = pd.DataFrame(sero_tensor[s, :, :])
    sero_df.index = y_true_df.index
    sero_df.to_csv(project_dir / "data" / "model" / "sero_dfs" / f"{sero}.csv", index=True)
    print("Saving sero: ", sero)
# Out:
# Saving sero:  DENV-1
# Saving sero:  DENV-2
# Saving sero:  DENV-3
# Saving sero:  DENV-4
# /var/folders/5f/9g0vtmkj22j_xbhxyrknnv140000gn/T/ipykernel_70184/573279697.py:22: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   denv_df['Collection date'] = pd.to_datetime(denv_df['Collection date'])

# %%
print(p_delay.shape)
# Out:
# (1, 1, 40)

# %%
# Create Serotype obj
sero_tensor = []
base_folder = project_dir / "data" / "model" / "sero_dfs"
files = [f for f in os.listdir(base_folder) if f.endswith('.csv')]
for file in files:
    file_path = os.path.join(base_folder, file)
    df = pd.read_csv(file_path)
    dates = df['Collection date']
    sero_df = df.drop(columns="Collection date")
    sero_tensor.append(sero_df)
sero_tensor = np.array(sero_tensor)

sero_dataset = SimulateSero(sero_tensor, dates, T=T, Q=Q, N=N, prop_vec=p_sero)

# %%
sero_

# %%
# Create count obj
delays_df = pd.read_csv(project_dir / "data" / "transformed" / "DENG_delays.csv")
delays_df['Collection date'] = pd.to_datetime(delays_df['Collection date'])

partial_count_dataset = PartialCountDataset(delays_df, D=D, M=M)
true_count_dataset = TrueCountDataset(delays_df)

# %%
# End of 2023 appears to have some incomplete data
if end_year == 2023:
    dates = list(pd.date_range(f"{start_year}-01-01",f"{end_year}-12-25", freq='D'))
else:
    dates = list(pd.date_range(f"{start_year}-01-01",f"{end_year}-12-31", freq='D'))
data_split_sizes = (np.array(data_split) * len(dates)).astype(int)

# Ensure dates line up fully, also removing 2023-12-31 as doesn't appear complete
data_split_sizes[-1] = len(dates) - data_split_sizes[:-1].sum()


train_dates = dates[:data_split_sizes[0]]
val_dates = dates[data_split_sizes[0]:data_split_sizes[0]+data_split_sizes[1]]
test_dates = dates[data_split_sizes[0]+data_split_sizes[1]:]

# %%
class SeroPNNDataset(Dataset):
    def __init__(self, partial_count_obj, true_count_obj, sero_obj, dates):
        self.partial_count_obj = partial_count_obj
        self.true_count_obj = true_count_obj
        self.sero_obj = sero_obj
        self.dates = dates
    
    def __len__(self):
        return len(self.dates)
    
    def __getitem__(self, index):
        date = self.dates[index]
        obs = self.partial_count_obj.get_obs(date)
        sero_obs = self.sero_obj.get_obs(date)
        prop_vec = self.sero_obj.get_prop_vec(date)
        y = self.true_count_obj.get_y_prop(date, prop_vec)
        dow = date.day_of_week
        return (obs, dow, sero_obs), y
    
set_seed(seed)
sero_props = pd.read_csv(project_dir / "data" / "transformed" / "sero_props.csv")


train_sero_pnn_dataset = SeroPNNDataset(partial_count_dataset, true_count_dataset, sero_dataset, train_dates)
val_sero_pnn_dataset = SeroPNNDataset(partial_count_dataset, true_count_dataset, sero_dataset, val_dates)
test_sero_pnn_dataset = SeroPNNDataset(partial_count_dataset, true_count_dataset,  sero_dataset, test_dates)

g = torch.Generator()
g.manual_seed(seed)

train_loader = DataLoader(train_sero_pnn_dataset, batch_size=32, shuffle=True, generator=g)
val_loader = DataLoader(val_sero_pnn_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_sero_pnn_dataset, batch_size=32, shuffle=False)

# %%
N = len(sero_dataset.get_prop_vec("2020-01-01"))
sero_pnn_model = SimSero(M=M, D=D, T=T, Q=Q, N=N, hidden_units = [16, 8], conv_channels = [16, 1], embedding_dim = 10, dropout_probs = [0.15, 0.1], device="cpu")
sero_pnn_train = SeroTrain("SeroPNN", lr=0.0003)
sero_pnn_train.train_model(sero_pnn_model, train_loader, val_loader)
# Out:
# Epoch 1 - Train loss: 1.22e+03 - Val loss: 1.13e+04 - ES count: 0
# Epoch 2 - Train loss: 9.02e+02 - Val loss: 1.14e+04 - ES count: 1
# Epoch 3 - Train loss: 8.59e+02 - Val loss: 1.15e+04 - ES count: 2
# Epoch 4 - Train loss: 8.3e+02 - Val loss: 9.32e+03 - ES count: 0
# Epoch 5 - Train loss: 7.56e+02 - Val loss: 9.84e+03 - ES count: 1
# Epoch 6 - Train loss: 7.02e+02 - Val loss: 1.09e+04 - ES count: 2
# Epoch 7 - Train loss: 7.84e+02 - Val loss: 8.96e+03 - ES count: 0
# Epoch 8 - Train loss: 6.83e+02 - Val loss: 7.23e+03 - ES count: 0
# Epoch 44 - Train loss: 2.2e+02 - Val loss: 2.09e+03 - ES count: 8
# Epoch 45 - Train loss: 1.8e+02 - Val loss: 1.34e+03 - ES count: 9
# Epoch 46 - Train loss: 1.73e+02 - Val loss: 1.22e+03 - ES count: 10
# Epoch 47 - Train loss: 1.69e+02 - Val loss: 1.45e+03 - ES count: 11
# Epoch 48 - Train loss: 1.51e+02 - Val loss: 1.32e+03 - ES count: 12
# Epoch 49 - Train loss: 1.46e+02 - Val loss: 1.11e+03 - ES count: 13
# Epoch 50 - Train loss: 1.42e+02 - Val loss: 1.26e+03 - ES count: 14
# Epoch 51 - Train loss: 1.45e+02 - Val loss: 1.12e+03 - ES count: 15
# Epoch 52 - Train loss: 1.47e+02 - Val loss: 9.41e+02 - ES count: 16
# Epoch 53 - Train loss: 1.35e+02 - Val loss: 9.57e+02 - ES count: 17
# Epoch 54 - Train loss: 1.28e+02 - Val loss: 1.29e+03 - ES count: 18
# Epoch 55 - Train loss: 1.33e+02 - Val loss: 1.06e+03 - ES count: 19
# Epoch 56 - Train loss: 1.3e+02 - Val loss: 9.52e+02 - ES count: 20
# Epoch 57 - Train loss: 1.29e+02 - Val loss: 1.02e+03 - ES count: 21
# Epoch 58 - Train loss: 1.3e+02 - Val loss: 8.26e+02 - ES count: 22
# Epoch 59 - Train loss: 1.22e+02 - Val loss: 1.1e+03 - ES count: 23
# Epoch 60 - Train loss: 1.26e+02 - Val loss: 1.1e+03 - ES count: 24
# Epoch 61 - Train loss: 1.35e+02 - Val loss: 1.12e+03 - ES count: 25
# Epoch 62 - Train loss: 1.24e+02 - Val loss: 8.26e+02 - ES count: 26
# Epoch 63 - Train loss: 1.16e+02 - Val loss: 7.68e+02 - ES count: 27
# Epoch 64 - Train loss: 1.25e+02 - Val loss: 9.51e+02 - ES count: 28
# Epoch 65 - Train loss: 1.17e+02 - Val loss: 8.77e+02 - ES count: 29
# Epoch 66 - Train loss: 1.18e+02 - Val loss: 9.7e+02 - ES count: 30

# %%
N = len(sero_dataset.get_prop_vec("2020-01-01"))
sero_pnn_model = SimSero(M=M, D=D, T=T, Q=Q, N=N, hidden_units = [16, 8], conv_channels = [16, 1], embedding_dim = 10, dropout_probs = [0.15, 0.1], device="cpu")
sero_pnn_model.load_state_dict(torch.load(project_dir /"src" / "outputs" / "weights" / f"weights-SeroPNN"))

sero_pnn_train_samples, train_y_true = eval_sero_pnn(train_sero_pnn_dataset, sero_pnn_model, N=N)
plot_sero_pnn_preds(sero_pnn_train_samples, train_sero_pnn_dataset, N, "SeroPNN Train Performance")

# crps = 0
# crps = sum([crps_ensemble(train_y_true[:,s], sero_pnn_train_samples[:,s,:]).mean() for s in range(N)])
# print(f"CRPS: {crps}")

# %%
sero_pnn_val_samples, val_y_true = eval_sero_pnn(val_sero_pnn_dataset, sero_pnn_model, N=N)
plot_sero_pnn_preds(sero_pnn_val_samples, val_sero_pnn_dataset, N, "SeroPNN Val Performance")

# crps = 0
# crps = sum([crps_ensemble(val_y_true[:,s], sero_pnn_val_samples[:,s,:]).mean() for s in range(N)])
# print(f"CRPS: {crps}")

# %%
sero_pnn_test_samples, test_y_true = eval_sero_pnn(test_sero_pnn_dataset, sero_pnn_model, N=N)
plot_sero_pnn_preds(sero_pnn_test_samples, test_sero_pnn_dataset, N, "SeroPNN Test Performance")

# crps = 0
# crps = sum([crps_ensemble(test_y_true[:,s,:,0], sero_pnn_test_samples[:,s,:]) for s in range(N)])
# print(f"CRPS: {crps}")

# %%
set_seed(seed)
sero_props = pd.read_csv(project_dir / "data" / "transformed" / "sero_props.csv")


train_sero_pnn_dataset = SeroPNNDataset(partial_count_dataset, true_count_dataset, sero_dataset, train_dates)
val_sero_pnn_dataset = SeroPNNDataset(partial_count_dataset, true_count_dataset, sero_dataset, val_dates)
test_sero_pnn_dataset = SeroPNNDataset(partial_count_dataset, true_count_dataset,  sero_dataset, test_dates)

g = torch.Generator()
g.manual_seed(seed)

train_loader = DataLoader(train_sero_pnn_dataset, batch_size=32, shuffle=True, generator=g)
val_loader = DataLoader(val_sero_pnn_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_sero_pnn_dataset, batch_size=32, shuffle=False)

# %%
N = len(sero_dataset.get_prop_vec("2020-01-01"))
direct_sero_model = DirectSero(M=M, D=D, T=T, Q=Q, N=N, hidden_units = [16, 8], conv_channels = [16, 1], embedding_dim = 10, dropout_probs = [0.15, 0.1], device="cpu")
direct_sero_train = DirectTrain("DirectSero", lr=0.0003)
direct_sero_train.train_model(direct_sero_model, train_loader, val_loader)
# Out:
# Epoch 1 - Train loss: 8.05e+03 - Val loss: 7.91e+04 - ES count: 0
# Epoch 2 - Train loss: 4.77e+03 - Val loss: 4.69e+04 - ES count: 0
# Epoch 3 - Train loss: 2.99e+03 - Val loss: 3.25e+04 - ES count: 0
# Epoch 4 - Train loss: 2.08e+03 - Val loss: 2.35e+04 - ES count: 0
# Epoch 5 - Train loss: 1.5e+03 - Val loss: 1.79e+04 - ES count: 0
# Epoch 6 - Train loss: 1.16e+03 - Val loss: 1.43e+04 - ES count: 0
# Epoch 7 - Train loss: 9.28e+02 - Val loss: 1.15e+04 - ES count: 0
# Epoch 8 - Train loss: 7.62e+02 - Val loss: 9.67e+03 - ES count: 0
# Epoch 9 - Train loss: 6.43e+02 - Val loss: 8.26e+03 - ES count: 0
# Epoch 10 - Train loss: 5.6e+02 - Val loss: 7.09e+03 - ES count: 0
# Epoch 11 - Train loss: 4.99e+02 - Val loss: 6.28e+03 - ES count: 0
# Epoch 12 - Train loss: 4.43e+02 - Val loss: 5.65e+03 - ES count: 0
# Epoch 13 - Train loss: 4.06e+02 - Val loss: 5.06e+03 - ES count: 0
# Epoch 14 - Train loss: 3.66e+02 - Val loss: 4.55e+03 - ES count: 0
# Epoch 15 - Train loss: 3.35e+02 - Val loss: 4.05e+03 - ES count: 0
# Epoch 16 - Train loss: 3.03e+02 - Val loss: 3.74e+03 - ES count: 0
# Epoch 17 - Train loss: 2.77e+02 - Val loss: 3.54e+03 - ES count: 0
# Epoch 18 - Train loss: 2.42e+02 - Val loss: 3.02e+03 - ES count: 0
# Epoch 19 - Train loss: 2.19e+02 - Val loss: 2.81e+03 - ES count: 0
# Epoch 20 - Train loss: 2e+02 - Val loss: 2.46e+03 - ES count: 0
# Epoch 21 - Train loss: 1.8e+02 - Val loss: 2.28e+03 - ES count: 0
# Epoch 22 - Train loss: 1.72e+02 - Val loss: 2.08e+03 - ES count: 0
# Epoch 23 - Train loss: 1.55e+02 - Val loss: 1.83e+03 - ES count: 0
# Epoch 24 - Train loss: 1.5e+02 - Val loss: 1.78e+03 - ES count: 0
# Epoch 25 - Train loss: 1.39e+02 - Val loss: 1.57e+03 - ES count: 0
# Epoch 26 - Train loss: 1.31e+02 - Val loss: 1.53e+03 - ES count: 0
# Epoch 27 - Train loss: 1.26e+02 - Val loss: 1.46e+03 - ES count: 0
# Epoch 104 - Train loss: 49.7 - Val loss: 6.33e+02 - ES count: 2
# Epoch 105 - Train loss: 48.7 - Val loss: 5.8e+02 - ES count: 0
# Epoch 106 - Train loss: 47.9 - Val loss: 5.92e+02 - ES count: 1
# Epoch 107 - Train loss: 47.9 - Val loss: 7.89e+02 - ES count: 2
# Epoch 108 - Train loss: 46.7 - Val loss: 5.76e+02 - ES count: 0
# Epoch 109 - Train loss: 46.5 - Val loss: 6.67e+02 - ES count: 1
# Epoch 110 - Train loss: 45.7 - Val loss: 6.43e+02 - ES count: 2
# Epoch 111 - Train loss: 46.0 - Val loss: 5.85e+02 - ES count: 3
# Epoch 112 - Train loss: 46.6 - Val loss: 6.09e+02 - ES count: 4
# Epoch 113 - Train loss: 45.1 - Val loss: 6.07e+02 - ES count: 5
# Epoch 114 - Train loss: 45.1 - Val loss: 8.33e+02 - ES count: 6
# Epoch 115 - Train loss: 45.1 - Val loss: 6.08e+02 - ES count: 7
# Epoch 116 - Train loss: 45.5 - Val loss: 6.66e+02 - ES count: 8
# Epoch 117 - Train loss: 44.2 - Val loss: 7.05e+02 - ES count: 9
# Epoch 118 - Train loss: 43.9 - Val loss: 6.73e+02 - ES count: 10
# Epoch 119 - Train loss: 44.1 - Val loss: 5.58e+02 - ES count: 0
# Epoch 120 - Train loss: 44.8 - Val loss: 7.49e+02 - ES count: 1
# Epoch 121 - Train loss: 44.4 - Val loss: 5.87e+02 - ES count: 2
# Epoch 122 - Train loss: 42.5 - Val loss: 6.33e+02 - ES count: 3
# Epoch 123 - Train loss: 44.2 - Val loss: 5.43e+02 - ES count: 0
# Epoch 124 - Train loss: 45.4 - Val loss: 5.21e+02 - ES count: 0
# Epoch 125 - Train loss: 44.5 - Val loss: 5.42e+02 - ES count: 1
# Epoch 126 - Train loss: 42.1 - Val loss: 5.05e+02 - ES count: 0
# Epoch 127 - Train loss: 41.4 - Val loss: 6.33e+02 - ES count: 1
# Epoch 128 - Train loss: 41.0 - Val loss: 6.33e+02 - ES count: 2
# Epoch 129 - Train loss: 41.6 - Val loss: 7.37e+02 - ES count: 3
# Epoch 130 - Train loss: 41.6 - Val loss: 7.36e+02 - ES count: 4
# Epoch 131 - Train loss: 44.9 - Val loss: 6.38e+02 - ES count: 5
# Epoch 132 - Train loss: 41.3 - Val loss: 6.26e+02 - ES count: 6
# Epoch 133 - Train loss: 41.1 - Val loss: 9.19e+02 - ES count: 7
# Epoch 134 - Train loss: 41.2 - Val loss: 6.71e+02 - ES count: 8
# Epoch 135 - Train loss: 40.2 - Val loss: 5.65e+02 - ES count: 9
# Epoch 136 - Train loss: 39.9 - Val loss: 6.34e+02 - ES count: 10
# Epoch 137 - Train loss: 39.7 - Val loss: 5.9e+02 - ES count: 11
# Epoch 138 - Train loss: 40.2 - Val loss: 6.64e+02 - ES count: 12
# Epoch 139 - Train loss: 38.7 - Val loss: 6.24e+02 - ES count: 13
# Epoch 140 - Train loss: 38.8 - Val loss: 6.25e+02 - ES count: 14
# Epoch 141 - Train loss: 40.4 - Val loss: 5.18e+02 - ES count: 15
# Epoch 180 - Train loss: 32.7 - Val loss: 4.44e+02 - ES count: 0
# Epoch 181 - Train loss: 32.3 - Val loss: 4.95e+02 - ES count: 1
# Epoch 182 - Train loss: 33.9 - Val loss: 6.37e+02 - ES count: 2
# Epoch 183 - Train loss: 32.7 - Val loss: 5.88e+02 - ES count: 3
# Epoch 184 - Train loss: 33.5 - Val loss: 5.14e+02 - ES count: 4
# Epoch 185 - Train loss: 32.2 - Val loss: 4.37e+02 - ES count: 0
# Epoch 186 - Train loss: 31.6 - Val loss: 5.79e+02 - ES count: 1
# Epoch 187 - Train loss: 32.0 - Val loss: 4.97e+02 - ES count: 2
# Epoch 188 - Train loss: 31.5 - Val loss: 5.4e+02 - ES count: 3
# Epoch 189 - Train loss: 31.3 - Val loss: 5.19e+02 - ES count: 4
# Epoch 190 - Train loss: 31.1 - Val loss: 5.08e+02 - ES count: 5
# Epoch 191 - Train loss: 31.4 - Val loss: 5.22e+02 - ES count: 6
# Epoch 192 - Train loss: 31.7 - Val loss: 5.26e+02 - ES count: 7
# Epoch 193 - Train loss: 30.7 - Val loss: 5.27e+02 - ES count: 8
# Epoch 194 - Train loss: 30.4 - Val loss: 4.89e+02 - ES count: 9
# Epoch 195 - Train loss: 29.9 - Val loss: 6.19e+02 - ES count: 10
# Epoch 196 - Train loss: 29.8 - Val loss: 5.35e+02 - ES count: 11
# Epoch 197 - Train loss: 30.1 - Val loss: 5.9e+02 - ES count: 12
# Epoch 198 - Train loss: 29.8 - Val loss: 4.72e+02 - ES count: 13
# Epoch 199 - Train loss: 30.6 - Val loss: 5.7e+02 - ES count: 14
# Epoch 200 - Train loss: 29.8 - Val loss: 5.35e+02 - ES count: 15

# %%
N = len(sero_dataset.get_prop_vec("2020-01-01"))
direct_sero_model = DirectSero(M=M, D=D, T=T, Q=Q, N=N, hidden_units = [16, 8], conv_channels = [16, 1], embedding_dim = 10, dropout_probs = [0.15, 0.1], device="cpu")
direct_sero_model.load_state_dict(torch.load(project_dir /"src" / "outputs" / "weights" / f"weights-DirectSero"))

sero_pnn_train_samples, train_y_true = eval_direct_sero(train_sero_pnn_dataset, direct_sero_model, N=N)
plot_sero_pnn_preds(sero_pnn_train_samples, train_sero_pnn_dataset, N, "DirectSero Train Performance")

# crps = 0
# crps = sum([crps_ensemble(train_y_true[:,s], sero_pnn_train_samples[:,s,:]).mean() for s in range(N)])
# print(f"CRPS: {crps}")

# %%
direct_sero_val_samples, val_y_true = eval_direct_sero(val_sero_pnn_dataset, direct_sero_model, N=N)
plot_sero_pnn_preds(direct_sero_val_samples, val_sero_pnn_dataset, N, "DirectSero Val Performance")

# crps = 0
# crps = sum([crps_ensemble(val_y_true[:,s], sero_pnn_val_samples[:,s,:]).mean() for s in range(N)])
# print(f"CRPS: {crps}")

# %%
direct_sero_test_samples, test_y_true = eval_direct_sero(test_sero_pnn_dataset, direct_sero_model, N=N)
plot_sero_pnn_preds(direct_sero_test_samples, test_sero_pnn_dataset, N, "DirectSero Test Performance")

# crps = 0
# crps = sum([crps_ensemble(test_y_true[:,s,:,0], sero_pnn_test_samples[:,s,:]) for s in range(N)])
# print(f"CRPS: {crps}")
