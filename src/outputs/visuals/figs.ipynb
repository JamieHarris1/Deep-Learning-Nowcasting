# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import sys
from pathlib import Path


sys.path.append(os.path.abspath('../src'))
project_dir = Path.cwd().parent.parent.parent

# Load images
img1 = mpimg.imread(project_dir / "src" / "outputs" / "visuals" / "same-day-nowcasts" / "NowcastPNN.png")
img2 = mpimg.imread(project_dir / "src" / "outputs" / "visuals" / "same-day-nowcasts" / "PropPNN.png")
img3 = mpimg.imread(project_dir / "src" / "outputs" / "visuals"/ "same-day-nowcasts" / "PropBNN.png")
img4 = mpimg.imread(project_dir / "src" / "outputs" / "visuals"/ "same-day-nowcasts" / "GLM.png")

# Create 2x2 subplot grid
fig, axes = plt.subplots(2, 2, figsize=(8, 8))  # adjust figsize as needed

# Flatten axes array for easy indexing
axes = axes.flatten()

# Plot images
axes[0].imshow(img1)
axes[0].axis('off')

axes[1].imshow(img2)
axes[1].axis('off')

axes[2].imshow(img3)
axes[2].axis('off')

# Leave the 4th subplot empty
axes[3].imshow(img4)
axes[3].axis('off')

plt.tight_layout()
plt.savefig(project_dir / "src" / "outputs" / "visuals" / "same-day-nowcasts" / "all_models.png", bbox_inches="tight", dpi=600)
plt.show()

# %%
# Load images
base_folder = project_dir / "src" / "outputs" / "visuals" / "serotype-nowcasts" / "raw"
img1 = mpimg.imread(base_folder / "const-props-DENV-1.png")
img2 = mpimg.imread(base_folder / "const-props-DENV-2.png")
img3 = mpimg.imread(base_folder / "const-props-DENV-3.png")
img4 = mpimg.imread(base_folder / "const-props-DENV-4.png")

# Create 2x2 subplot grid
fig, axes = plt.subplots(2, 2, figsize=(8, 8))  # adjust figsize as needed

# Flatten axes array for easy indexing
axes = axes.flatten()

# Plot images
axes[0].imshow(img1)
axes[0].axis('off')

axes[1].imshow(img2)
axes[1].axis('off')

axes[2].imshow(img3)
axes[2].axis('off')

axes[3].imshow(img4)
axes[3].axis('off')


plt.tight_layout()
plt.savefig(project_dir / "src" / "outputs" / "visuals" / "serotype-nowcasts" / "sero-const-props", bbox_inches="tight", dpi=600)
plt.show()

# %%
# Load images
img1 = mpimg.imread(base_folder / "low-const-props-DENV-1.png")
img2 = mpimg.imread(base_folder / "low-const-props-DENV-2.png")
img3 = mpimg.imread(base_folder / "low-const-props-DENV-3.png")
img4 = mpimg.imread(base_folder / "low-const-props-DENV-4.png")

# Create 2x2 subplot grid
fig, axes = plt.subplots(2, 2, figsize=(8, 8))  # adjust figsize as needed

# Flatten axes array for easy indexing
axes = axes.flatten()

# Plot images
axes[0].imshow(img1)
axes[0].axis('off')

axes[1].imshow(img2)
axes[1].axis('off')

axes[2].imshow(img3)
axes[2].axis('off')

axes[3].imshow(img4)
axes[3].axis('off')


plt.tight_layout()
plt.savefig(project_dir / "src" / "outputs" / "visuals" / "serotype-nowcasts" / "sero-low-const-props", bbox_inches="tight", dpi=600)
plt.show()

# %%
# Load images
img1 = mpimg.imread(base_folder / "time-props-DENV-1.png")
img2 = mpimg.imread(base_folder / "time-props-DENV-2.png")
img3 = mpimg.imread(base_folder / "time-props-DENV-3.png")
img4 = mpimg.imread(base_folder / "time-props-DENV-4.png")

# Create 2x2 subplot grid
fig, axes = plt.subplots(2, 2, figsize=(8, 8))  # adjust figsize as needed

# Flatten axes array for easy indexing
axes = axes.flatten()

# Plot images
axes[0].imshow(img1)
axes[0].axis('off')

axes[1].imshow(img2)
axes[1].axis('off')

axes[2].imshow(img3)
axes[2].axis('off')

axes[3].imshow(img4)
axes[3].axis('off')


plt.tight_layout()
plt.savefig(project_dir / "src" / "outputs" / "visuals" / "serotype-nowcasts" / "sero-time-props", bbox_inches="tight", dpi=600)

plt.show()
